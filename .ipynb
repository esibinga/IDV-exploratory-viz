# %% [markdown]
# My goal here is to create a csv from genealogical data I have in a GEDCOM file. Ideally I'd like the data to be a JSON file so that I can use it for hierarchical data viz, but I've had trouble converting directly from GEDCOM to JSON. I'm going to try the intermediate step of CSV here using a GEDCOM parse package and pandas.

# %%
pip install python-gedcom
# Out:
# Collecting python-gedcom
#   Downloading https://files.pythonhosted.org/packages/1d/c0/20b56a9cf44fac3c25799e5a84b6a719ec7d7bc47501c9fe2b484bdabba5/python_gedcom-1.0.0-py2.py3-none-any.whl
# Installing collected packages: python-gedcom
# Successfully installed python-gedcom-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#install gedcom packages
from gedcom.element.individual import IndividualElement
from gedcom.parser import Parser

# %%
import os
os.getcwd()
# Out:
# '/Users/evasibinga'

# %%
os.chdir('./IDV-exploratory-viz/')

# %%
#install dataframe packages needed
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Users/evasibinga/IDV-exploratory-viz'

# %%
#create empty dataframe ## didn't end up using this but it was a helpful starting place
col_names = ['INDI', 'first', 'last', 'full_name', 'family', 'sex', 'DOB', 'DOD', 'birthplace', 'deathplace', 'generation', 'level', 'parent_id' ]
my_df = pd.DataFrame(columns=col_names)

# %%
my_df
# Out:
# Empty DataFrame
# Columns: [INDI, first, last, full_name, family, sex, DOB, DOD, birthplace, deathplace, generation, parent_id]
# Index: []

# %%
#file path to my gedcom file
file_path = 'data/JGB_MHB.ged'

# %%
#initialize gedcom parser
gedcom_parser = Parser()

# %%
gedcom_parser.parse_file(file_path)

# %%
root_child_elements = gedcom_parser.get_root_child_elements()

# %%
root_child_elements
# Out:
# [<gedcom.element.element.Element at 0x11c821588>,
#  <gedcom.element.individual.IndividualElement at 0x11c821c50>,
#  <gedcom.element.individual.IndividualElement at 0x11c8379e8>,
#  <gedcom.element.individual.IndividualElement at 0x11c8466d8>,
#  <gedcom.element.individual.IndividualElement at 0x11c8514a8>,
#  <gedcom.element.individual.IndividualElement at 0x11c8609e8>,
#  <gedcom.element.individual.IndividualElement at 0x11c86c390>,
#  <gedcom.element.individual.IndividualElement at 0x11c888630>,
#  <gedcom.element.individual.IndividualElement at 0x11c8a1898>,
#  <gedcom.element.individual.IndividualElement at 0x11c8b7f98>,
#  <gedcom.element.individual.IndividualElement at 0x10a4daa58>,
#  <gedcom.element.individual.IndividualElement at 0x10a4eb9e8>,
#  <gedcom.element.individual.IndividualElement at 0x10a4f04e0>,
#  <gedcom.element.individual.IndividualElement at 0x10a4f2400>,
#  <gedcom.element.individual.IndividualElement at 0x10a4f2ef0>,
#  <gedcom.element.individual.IndividualElement at 0x10a4f8b00>,
#  <gedcom.element.individual.IndividualElement at 0x10a5078d0>,
#  <gedcom.element.individual.IndividualElement at 0x10a51aef0>,
#  <gedcom.element.individual.IndividualElement at 0x10a51b8d0>,
#  <gedcom.element.individual.IndividualElement at 0x10a51d2b0>,
#  <gedcom.element.individual.IndividualElement at 0x10a526a58>,
#  <gedcom.element.individual.IndividualElement at 0x10a531d68>,
#  <gedcom.element.individual.IndividualElement at 0x10a541240>,
#  <gedcom.element.individual.IndividualElement at 0x10a545d68>,
#  <gedcom.element.individual.IndividualElement at 0x10c29e358>,
#  <gedcom.element.individual.IndividualElement at 0x11bfc2e48>,
#  <gedcom.element.individual.IndividualElement at 0x11bc8aa20>,
#  <gedcom.element.individual.IndividualElement at 0x10c2a8f60>,
#  <gedcom.element.individual.IndividualElement at 0x10c2bd470>,
#  <gedcom.element.individual.IndividualElement at 0x10c2c9358>,
#  <gedcom.element.individual.IndividualElement at 0x10c2d7828>,
#  <gedcom.element.individual.IndividualElement at 0x10c2e4be0>,
#  <gedcom.element.individual.IndividualElement at 0x10c2ea908>,
#  <gedcom.element.individual.IndividualElement at 0x10c3022e8>,
#  <gedcom.element.individual.IndividualElement at 0x11c8ea198>,
#  <gedcom.element.individual.IndividualElement at 0x11c8f7898>,
#  <gedcom.element.individual.IndividualElement at 0x11c908710>,
#  <gedcom.element.individual.IndividualElement at 0x11c919c50>,
#  <gedcom.element.individual.IndividualElement at 0x11c9235f8>,
#  <gedcom.element.individual.IndividualElement at 0x11c93d2e8>,
#  <gedcom.element.individual.IndividualElement at 0x11c943dd8>,
#  <gedcom.element.individual.IndividualElement at 0x11c94a588>,
#  <gedcom.element.individual.IndividualElement at 0x11c94f2b0>,
#  <gedcom.element.individual.IndividualElement at 0x11c952cc0>,
#  <gedcom.element.individual.IndividualElement at 0x11c954940>,
#  <gedcom.element.individual.IndividualElement at 0x11c954e80>,
#  <gedcom.element.individual.IndividualElement at 0x11c958518>,
#  <gedcom.element.individual.IndividualElement at 0x11c95a9b0>,
#  <gedcom.element.individual.IndividualElement at 0x11c95d0f0>,
#  <gedcom.element.individual.IndividualElement at 0x11c95f710>,
#  <gedcom.element.individual.IndividualElement at 0x11c9610f0>,
#  <gedcom.element.individual.IndividualElement at 0x11c968b38>,
#  <gedcom.element.individual.IndividualElement at 0x11c9739b0>,
#  <gedcom.element.individual.IndividualElement at 0x11c975470>,
#  <gedcom.element.individual.IndividualElement at 0x11c975a90>,
#  <gedcom.element.individual.IndividualElement at 0x11c97a9b0>,
#  <gedcom.element.individual.IndividualElement at 0x11c97de48>,
#  <gedcom.element.individual.IndividualElement at 0x11c982d68>,
#  <gedcom.element.individual.IndividualElement at 0x11c990320>,
#  <gedcom.element.individual.IndividualElement at 0x11c994518>,
#  <gedcom.element.individual.IndividualElement at 0x11c996390>,
#  <gedcom.element.individual.IndividualElement at 0x11c998208>,
#  <gedcom.element.individual.IndividualElement at 0x11c99b978>,
#  <gedcom.element.individual.IndividualElement at 0x11c99d9e8>,
#  <gedcom.element.individual.IndividualElement at 0x11c9a0908>,
#  <gedcom.element.individual.IndividualElement at 0x11c9a1cc0>,
#  <gedcom.element.individual.IndividualElement at 0x11c9a6198>,
#  <gedcom.element.individual.IndividualElement at 0x11c9aa550>,
#  <gedcom.element.individual.IndividualElement at 0x11c9b1cc0>,
#  <gedcom.element.individual.IndividualElement at 0x11c9b62b0>,
#  <gedcom.element.individual.IndividualElement at 0x11c9bc908>,
#  <gedcom.element.individual.IndividualElement at 0x11c9c2080>,
#  <gedcom.element.individual.IndividualElement at 0x11c9c2ba8>,
#  <gedcom.element.individual.IndividualElement at 0x11c9c6d68>,
#  <gedcom.element.individual.IndividualElement at 0x11c9ca278>,
#  <gedcom.element.individual.IndividualElement at 0x11c9cf470>,
#  <gedcom.element.individual.IndividualElement at 0x11c9d1748>,
#  <gedcom.element.individual.IndividualElement at 0x11c9d49e8>,
#  <gedcom.element.individual.IndividualElement at 0x11c9d6400>,
#  <gedcom.element.individual.IndividualElement at 0x11c9dae80>,
#  <gedcom.element.individual.IndividualElement at 0x11c9df198>,
#  <gedcom.element.individual.IndividualElement at 0x11c9e11d0>,
#  <gedcom.element.individual.IndividualElement at 0x11c9e17b8>,
#  <gedcom.element.individual.IndividualElement at 0x11c9e4160>,
#  <gedcom.element.individual.IndividualElement at 0x11c9ec780>,
#  <gedcom.element.individual.IndividualElement at 0x11c9f1320>,
#  <gedcom.element.individual.IndividualElement at 0x11c9f5400>,
#  <gedcom.element.individual.IndividualElement at 0x11c9f6f28>,
#  <gedcom.element.individual.IndividualElement at 0x11c9faef0>,
#  <gedcom.element.individual.IndividualElement at 0x11c9ff828>,
#  <gedcom.element.individual.IndividualElement at 0x11ca01908>,
#  <gedcom.element.individual.IndividualElement at 0x11ca046d8>,
#  <gedcom.element.individual.IndividualElement at 0x11ca05fd0>,
#  <gedcom.element.individual.IndividualElement at 0x11ca0bac8>,
#  <gedcom.element.individual.IndividualElement at 0x11ca117b8>,
#  <gedcom.element.individual.IndividualElement at 0x11ca164a8>,
#  <gedcom.element.individual.IndividualElement at 0x11ca16908>,
#  <gedcom.element.individual.IndividualElement at 0x11ca16d68>,
#  <gedcom.element.individual.IndividualElement at 0x11ca19208>,
#  <gedcom.element.individual.IndividualElement at 0x11ca19a58>,
#  <gedcom.element.individual.IndividualElement at 0x11ca1a470>,
#  <gedcom.element.individual.IndividualElement at 0x11ca1af98>,
#  <gedcom.element.individual.IndividualElement at 0x11ca1e588>,
#  <gedcom.element.individual.IndividualElement at 0x11ca1ec88>,
#  <gedcom.element.individual.IndividualElement at 0x11ca1f6a0>,
#  <gedcom.element.individual.IndividualElement at 0x11ca24908>,
#  <gedcom.element.individual.IndividualElement at 0x11ca2ccf8>,
#  <gedcom.element.individual.IndividualElement at 0x11ca2e630>,
#  <gedcom.element.individual.IndividualElement at 0x11ca343c8>,
#  <gedcom.element.individual.IndividualElement at 0x11ca39668>,
#  <gedcom.element.individual.IndividualElement at 0x11ca3f8d0>,
#  <gedcom.element.individual.IndividualElement at 0x11ca41b00>,
#  <gedcom.element.individual.IndividualElement at 0x11ca44080>,
#  <gedcom.element.individual.IndividualElement at 0x11ca46780>,
#  <gedcom.element.individual.IndividualElement at 0x11ca49b38>,
#  <gedcom.element.individual.IndividualElement at 0x11ca4ba20>,
#  <gedcom.element.individual.IndividualElement at 0x11ca4e2b0>,
#  <gedcom.element.individual.IndividualElement at 0x11ca503c8>,
#  <gedcom.element.individual.IndividualElement at 0x11ca50f60>,
#  <gedcom.element.individual.IndividualElement at 0x11ca53cc0>,
#  <gedcom.element.individual.IndividualElement at 0x11ca59e80>,
#  <gedcom.element.individual.IndividualElement at 0x11ca5f8d0>,
#  <gedcom.element.individual.IndividualElement at 0x11ca65b38>,
#  <gedcom.element.individual.IndividualElement at 0x11ca6aba8>,
#  <gedcom.element.individual.IndividualElement at 0x11ca71198>,
#  <gedcom.element.individual.IndividualElement at 0x11ca76748>,
#  <gedcom.element.individual.IndividualElement at 0x11ca7b160>,
#  <gedcom.element.individual.IndividualElement at 0x11ca81390>,
#  <gedcom.element.individual.IndividualElement at 0x11ca84da0>,
#  <gedcom.element.individual.IndividualElement at 0x11ca8c7f0>,
#  <gedcom.element.individual.IndividualElement at 0x11ca8cf98>,
#  <gedcom.element.individual.IndividualElement at 0x11ca8ed30>,
#  <gedcom.element.individual.IndividualElement at 0x11ca918d0>,
#  <gedcom.element.individual.IndividualElement at 0x11ca91dd8>,
#  <gedcom.element.individual.IndividualElement at 0x11ca97da0>,
#  <gedcom.element.individual.IndividualElement at 0x11ca99588>,
#  <gedcom.element.individual.IndividualElement at 0x11ca99a20>,
#  <gedcom.element.individual.IndividualElement at 0x11ca99eb8>,
#  <gedcom.element.individual.IndividualElement at 0x11ca9b390>,
#  <gedcom.element.individual.IndividualElement at 0x11ca9b898>,
#  <gedcom.element.individual.IndividualElement at 0x11ca9bda0>,
#  <gedcom.element.individual.IndividualElement at 0x11ca9e278>,
#  <gedcom.element.individual.IndividualElement at 0x11ca9e780>,
#  <gedcom.element.individual.IndividualElement at 0x11ca9ecc0>,
#  <gedcom.element.individual.IndividualElement at 0x11caa0198>,
#  <gedcom.element.individual.IndividualElement at 0x11caa0630>,
#  <gedcom.element.individual.IndividualElement at 0x11caa0e10>,
#  <gedcom.element.individual.IndividualElement at 0x11caa22b0>,
#  <gedcom.element.individual.IndividualElement at 0x11caa2710>,
#  <gedcom.element.individual.IndividualElement at 0x11caa2b70>,
#  <gedcom.element.individual.IndividualElement at 0x11caa40f0>,
#  <gedcom.element.individual.IndividualElement at 0x11caa4400>,
#  <gedcom.element.individual.IndividualElement at 0x11caa4710>,
#  <gedcom.element.individual.IndividualElement at 0x11caa4b70>,
#  <gedcom.element.individual.IndividualElement at 0x11caa74e0>,
#  <gedcom.element.individual.IndividualElement at 0x11caa7940>,
#  <gedcom.element.individual.IndividualElement at 0x11caaa0b8>,
#  <gedcom.element.individual.IndividualElement at 0x11caaa5f8>,
#  <gedcom.element.individual.IndividualElement at 0x11caaab38>,
#  <gedcom.element.individual.IndividualElement at 0x11caac0b8>,
#  <gedcom.element.individual.IndividualElement at 0x11caac3c8>,
#  <gedcom.element.individual.IndividualElement at 0x11caac828>,
#  <gedcom.element.individual.IndividualElement at 0x11caacc88>,
#  <gedcom.element.individual.IndividualElement at 0x11caaf278>,
#  <gedcom.element.individual.IndividualElement at 0x11caaf6d8>,
#  <gedcom.element.individual.IndividualElement at 0x11cab16a0>,
#  <gedcom.element.individual.IndividualElement at 0x11cab1b00>,
#  <gedcom.element.individual.IndividualElement at 0x11cab1f60>,
#  <gedcom.element.individual.IndividualElement at 0x11cab4400>,
#  <gedcom.element.individual.IndividualElement at 0x11cab4da0>,
#  <gedcom.element.individual.IndividualElement at 0x11cab7240>,
#  <gedcom.element.individual.IndividualElement at 0x11cab7d30>,
#  <gedcom.element.individual.IndividualElement at 0x11caba860>,
#  <gedcom.element.individual.IndividualElement at 0x11cabc860>,
#  <gedcom.element.individual.IndividualElement at 0x11cabcba8>,
#  <gedcom.element.individual.IndividualElement at 0x11cabf0f0>,
#  <gedcom.element.individual.IndividualElement at 0x11cabfbe0>,
#  <gedcom.element.individual.IndividualElement at 0x11cac0710>,
#  <gedcom.element.individual.IndividualElement at 0x11cac31d0>,
#  <gedcom.element.individual.IndividualElement at 0x11cac3cc0>,
#  <gedcom.element.individual.IndividualElement at 0x11cac67f0>,
#  <gedcom.element.individual.IndividualElement at 0x11cac7320>,
#  <gedcom.element.individual.IndividualElement at 0x11cacd278>,
#  <gedcom.element.individual.IndividualElement at 0x11cacd6d8>,
#  <gedcom.element.individual.IndividualElement at 0x11cacdb38>,
#  <gedcom.element.individual.IndividualElement at 0x11cacdf98>,
#  <gedcom.element.individual.IndividualElement at 0x11cad0438>,
#  <gedcom.element.individual.IndividualElement at 0x11cad0898>,
#  <gedcom.element.individual.IndividualElement at 0x11cad0cf8>,
#  <gedcom.element.individual.IndividualElement at 0x11cad1198>,
#  <gedcom.element.individual.IndividualElement at 0x11cad15f8>,
#  <gedcom.element.individual.IndividualElement at 0x11cad1a58>,
#  <gedcom.element.individual.IndividualElement at 0x11cad4b70>,
#  <gedcom.element.individual.IndividualElement at 0x11cad4fd0>,
#  <gedcom.element.individual.IndividualElement at 0x11cad6470>,
#  <gedcom.element.individual.IndividualElement at 0x11cad68d0>,
#  <gedcom.element.individual.IndividualElement at 0x11cad6d30>,
#  <gedcom.element.individual.IndividualElement at 0x11cad91d0>,
#  <gedcom.element.individual.IndividualElement at 0x11cad9b70>,
#  <gedcom.element.individual.IndividualElement at 0x11cadc048>,
#  <gedcom.element.individual.IndividualElement at 0x11cadc4a8>,
#  <gedcom.element.individual.IndividualElement at 0x11cadc908>,
#  <gedcom.element.individual.IndividualElement at 0x11cadcd68>,
#  <gedcom.element.individual.IndividualElement at 0x11cadf9e8>,
#  <gedcom.element.individual.IndividualElement at 0x11cadfe48>,
#  <gedcom.element.individual.IndividualElement at 0x11cae12e8>,
#  <gedcom.element.individual.IndividualElement at 0x11cae1f60>,
#  <gedcom.element.individual.IndividualElement at 0x11cae42b0>,
#  <gedcom.element.individual.IndividualElement at 0x11cae47f0>,
#  <gedcom.element.individual.IndividualElement at 0x11cae4c50>,
#  <gedcom.element.individual.IndividualElement at 0x11cae60f0>,
#  <gedcom.element.individual.IndividualElement at 0x11cae6400>,
#  <gedcom.element.individual.IndividualElement at 0x11cae6710>,
#  <gedcom.element.individual.IndividualElement at 0x11cae6b70>,
#  <gedcom.element.individual.IndividualElement at 0x11cae6fd0>,
#  <gedcom.element.individual.IndividualElement at 0x11cae7470>,
#  <gedcom.element.individual.IndividualElement at 0x11cae78d0>,
#  <gedcom.element.individual.IndividualElement at 0x11cae7d30>,
#  <gedcom.element.individual.IndividualElement at 0x11caea208>,
#  <gedcom.element.individual.IndividualElement at 0x11caea710>,
#  <gedcom.element.individual.IndividualElement at 0x11caeac18>,
#  <gedcom.element.individual.IndividualElement at 0x11caec240>,
#  <gedcom.element.individual.IndividualElement at 0x11caec6a0>,
#  <gedcom.element.individual.IndividualElement at 0x11caecb00>,
#  <gedcom.element.individual.IndividualElement at 0x11caef048>,
#  <gedcom.element.individual.IndividualElement at 0x11caef550>,
#  <gedcom.element.individual.IndividualElement at 0x11caefa58>,
#  <gedcom.element.individual.IndividualElement at 0x11caeff60>,
#  <gedcom.element.individual.IndividualElement at 0x11caf14a8>,
#  <gedcom.element.individual.IndividualElement at 0x11caf1a90>,
#  <gedcom.element.individual.IndividualElement at 0x11caf1f98>,
#  <gedcom.element.individual.IndividualElement at 0x11caf4518>,
#  <gedcom.element.individual.IndividualElement at 0x11caf4a58>,
#  <gedcom.element.individual.IndividualElement at 0x11caf4f60>,
#  <gedcom.element.individual.IndividualElement at 0x11caf6a90>,
#  <gedcom.element.individual.IndividualElement at 0x11caf8748>,
#  <gedcom.element.individual.IndividualElement at 0x11caf8ba8>,
#  <gedcom.element.individual.IndividualElement at 0x11caf8eb8>,
#  <gedcom.element.individual.IndividualElement at 0x11cafb358>,
#  <gedcom.element.individual.IndividualElement at 0x11cafb668>,
#  <gedcom.element.individual.IndividualElement at 0x11cafbb70>,
#  <gedcom.element.individual.IndividualElement at 0x11cafc0b8>,
#  <gedcom.element.individual.IndividualElement at 0x11cafc5c0>,
#  <gedcom.element.individual.IndividualElement at 0x11caffbe0>,
#  <gedcom.element.individual.IndividualElement at 0x11cb05240>,
#  <gedcom.element.individual.IndividualElement at 0x11cb05748>,
#  <gedcom.element.individual.IndividualElement at 0x11cb05d30>,
#  <gedcom.element.individual.IndividualElement at 0x11cb07898>,
#  <gedcom.element.individual.IndividualElement at 0x11cb0aa58>,
#  <gedcom.element.individual.IndividualElement at 0x11cb0c470>,
#  <gedcom.element.individual.IndividualElement at 0x11cb0c908>,
#  <gedcom.element.individual.IndividualElement at 0x11cb0cd68>,
#  <gedcom.element.individual.IndividualElement at 0x11cb0e208>,
#  <gedcom.element.individual.IndividualElement at 0x11cb0e710>,
#  <gedcom.element.individual.IndividualElement at 0x11cb0ecf8>,
#  <gedcom.element.individual.IndividualElement at 0x11cb11a90>,
#  <gedcom.element.individual.IndividualElement at 0x11cb11ef0>,
#  <gedcom.element.individual.IndividualElement at 0x11cb13390>,
#  <gedcom.element.individual.IndividualElement at 0x11cb13cc0>,
#  <gedcom.element.individual.IndividualElement at 0x11cb16160>,
#  <gedcom.element.individual.IndividualElement at 0x11cb16668>,
#  <gedcom.element.individual.IndividualElement at 0x11cb16ac8>,
#  <gedcom.element.individual.IndividualElement at 0x11cb16f28>,
#  <gedcom.element.individual.IndividualElement at 0x11cb173c8>,
#  <gedcom.element.individual.IndividualElement at 0x11cb178d0>,
#  <gedcom.element.individual.IndividualElement at 0x11cb17dd8>,
#  <gedcom.element.individual.IndividualElement at 0x11cb1b2b0>,
#  <gedcom.element.individual.IndividualElement at 0x11cb1b748>,
#  <gedcom.element.individual.IndividualElement at 0x11cb1bc50>,
#  <gedcom.element.individual.IndividualElement at 0x11cb1c128>,
#  <gedcom.element.individual.IndividualElement at 0x11cb1c5c0>,
#  <gedcom.element.individual.IndividualElement at 0x11cb1ca20>,
#  <gedcom.element.individual.IndividualElement at 0x11cb1ce80>,
#  <gedcom.element.individual.IndividualElement at 0x11cb1e320>,
#  <gedcom.element.individual.IndividualElement at 0x11cb1e780>,
#  <gedcom.element.individual.IndividualElement at 0x11cb1ebe0>,
#  <gedcom.element.individual.IndividualElement at 0x11cb21080>,
#  <gedcom.element.family.FamilyElement at 0x11cb214a8>,
#  <gedcom.element.family.FamilyElement at 0x11cb23f28>,
#  <gedcom.element.family.FamilyElement at 0x11cb246a0>,
#  <gedcom.element.family.FamilyElement at 0x11cb27208>,
#  <gedcom.element.family.FamilyElement at 0x11cb27e80>,
#  <gedcom.element.family.FamilyElement at 0x11cb29d30>,
#  <gedcom.element.family.FamilyElement at 0x11cb2c9e8>,
#  <gedcom.element.family.FamilyElement at 0x11cb2e438>,
#  <gedcom.element.family.FamilyElement at 0x11cb2f8d0>,
#  <gedcom.element.family.FamilyElement at 0x11cb34828>,
#  <gedcom.element.family.FamilyElement at 0x11cb362e8>,
#  <gedcom.element.family.FamilyElement at 0x11cb36f60>,
#  <gedcom.element.family.FamilyElement at 0x11cb3b048>,
#  <gedcom.element.family.FamilyElement at 0x11cb3b828>,
#  <gedcom.element.family.FamilyElement at 0x11cb3c390>,
#  <gedcom.element.family.FamilyElement at 0x11cb3c978>,
#  <gedcom.element.family.FamilyElement at 0x11cb3cc18>,
#  <gedcom.element.family.FamilyElement at 0x11cb3e8d0>,
#  <gedcom.element.family.FamilyElement at 0x11cb3ed68>,
#  <gedcom.element.family.FamilyElement at 0x11cb41c18>,
#  <gedcom.element.family.FamilyElement at 0x11cb41eb8>,
#  <gedcom.element.family.FamilyElement at 0x11cb42630>,
#  <gedcom.element.family.FamilyElement at 0x11cb46240>,
#  <gedcom.element.family.FamilyElement at 0x11cb46a20>,
#  <gedcom.element.family.FamilyElement at 0x11cb47198>,
#  <gedcom.element.family.FamilyElement at 0x11cb478d0>,
#  <gedcom.element.family.FamilyElement at 0x11cb48cc0>,
#  <gedcom.element.family.FamilyElement at 0x11cb4cb70>,
#  <gedcom.element.family.FamilyElement at 0x11cb4d828>,
#  <gedcom.element.family.FamilyElement at 0x11cb50978>,
#  <gedcom.element.family.FamilyElement at 0x11cb52438>,
#  <gedcom.element.family.FamilyElement at 0x11cb550f0>,
#  <gedcom.element.family.FamilyElement at 0x11cb558d0>,
#  <gedcom.element.family.FamilyElement at 0x11cb580f0>,
#  <gedcom.element.family.FamilyElement at 0x11cb58f60>,
#  <gedcom.element.family.FamilyElement at 0x11cb59240>,
#  <gedcom.element.family.FamilyElement at 0x11cb59e10>,
#  <gedcom.element.family.FamilyElement at 0x11cb5b390>,
#  <gedcom.element.family.FamilyElement at 0x11cb5b7b8>,
#  <gedcom.element.family.FamilyElement at 0x11cb5e470>,
#  <gedcom.element.family.FamilyElement at 0x11cb5ee80>,
#  <gedcom.element.family.FamilyElement at 0x11cb617f0>,
#  <gedcom.element.family.FamilyElement at 0x11cb61fd0>,
#  <gedcom.element.family.FamilyElement at 0x11cb639e8>,
#  <gedcom.element.family.FamilyElement at 0x11cb657f0>,
#  <gedcom.element.family.FamilyElement at 0x11cb674a8>,
#  <gedcom.element.family.FamilyElement at 0x11cb678d0>,
#  <gedcom.element.family.FamilyElement at 0x11cb6a710>,
#  <gedcom.element.family.FamilyElement at 0x11cb6c518>,
#  <gedcom.element.family.FamilyElement at 0x11cb6e128>,
#  <gedcom.element.family.FamilyElement at 0x11cb6ef98>,
#  <gedcom.element.family.FamilyElement at 0x11cb70b00>,
#  <gedcom.element.family.FamilyElement at 0x11cb72518>,
#  <gedcom.element.family.FamilyElement at 0x11cb72908>,
#  <gedcom.element.family.FamilyElement at 0x11cb741d0>,
#  <gedcom.element.family.FamilyElement at 0x11cb74da0>,
#  <gedcom.element.family.FamilyElement at 0x11cb77518>,
#  <gedcom.element.family.FamilyElement at 0x11cb77ef0>,
#  <gedcom.element.family.FamilyElement at 0x11cb78320>,
#  <gedcom.element.family.FamilyElement at 0x11cb78e48>,
#  <gedcom.element.family.FamilyElement at 0x11cb7a3c8>,
#  <gedcom.element.family.FamilyElement at 0x11cb7ada0>,
#  <gedcom.element.family.FamilyElement at 0x11cb7dc50>,
#  <gedcom.element.family.FamilyElement at 0x11cb7f5c0>,
#  <gedcom.element.family.FamilyElement at 0x11cb7ff28>,
#  <gedcom.element.family.FamilyElement at 0x11cb81588>,
#  <gedcom.element.family.FamilyElement at 0x11cb83198>,
#  <gedcom.element.family.FamilyElement at 0x11cb852e8>,
#  <gedcom.element.family.FamilyElement at 0x11cb858d0>,
#  <gedcom.element.family.FamilyElement at 0x11cb87240>,
#  <gedcom.element.family.FamilyElement at 0x11cb878d0>,
#  <gedcom.element.family.FamilyElement at 0x11cb89588>,
#  <gedcom.element.family.FamilyElement at 0x11cb89d68>,
#  <gedcom.element.family.FamilyElement at 0x11cb8ceb8>,
#  <gedcom.element.family.FamilyElement at 0x11cb8eb70>,
#  <gedcom.element.family.FamilyElement at 0x11cb90390>,
#  <gedcom.element.family.FamilyElement at 0x11cb90e10>,
#  <gedcom.element.family.FamilyElement at 0x11cb936d8>,
#  <gedcom.element.family.FamilyElement at 0x11cb952e8>,
#  <gedcom.element.family.FamilyElement at 0x11cb95a20>,
#  <gedcom.element.family.FamilyElement at 0x11cb97978>,
#  <gedcom.element.family.FamilyElement at 0x11cb99390>,
#  <gedcom.element.family.FamilyElement at 0x11cb998d0>,
#  <gedcom.element.family.FamilyElement at 0x11cb9b630>,
#  <gedcom.element.family.FamilyElement at 0x11cb9bf60>,
#  <gedcom.element.family.FamilyElement at 0x11cb9e4e0>,
#  <gedcom.element.family.FamilyElement at 0x11cb9ea20>,
#  <gedcom.element.family.FamilyElement at 0x11cb9fac8>,
#  <gedcom.element.family.FamilyElement at 0x11cba1240>,
#  <gedcom.element.family.FamilyElement at 0x11cba18d0>,
#  <gedcom.element.family.FamilyElement at 0x11cba1e10>,
#  <gedcom.element.family.FamilyElement at 0x11cba4390>,
#  <gedcom.element.family.FamilyElement at 0x11cba48d0>,
#  <gedcom.element.element.Element at 0x11cba4c18>,
#  <gedcom.element.element.Element at 0x11cba4d68>,
#  <gedcom.element.element.Element at 0x11cba4eb8>,
#  <gedcom.element.element.Element at 0x11cba5198>,
#  <gedcom.element.element.Element at 0x11cba5588>,
#  <gedcom.element.element.Element at 0x11cba5978>,
#  <gedcom.element.element.Element at 0x11cba5d68>,
#  <gedcom.element.element.Element at 0x11cba9198>,
#  <gedcom.element.element.Element at 0x11cba9588>,
#  <gedcom.element.element.Element at 0x11cba9978>,
#  <gedcom.element.element.Element at 0x11cba9d68>,
#  <gedcom.element.element.Element at 0x11cbaa198>,
#  <gedcom.element.element.Element at 0x11cbaa588>,
#  <gedcom.element.element.Element at 0x11cbaa978>,
#  <gedcom.element.element.Element at 0x11cbaad68>,
#  <gedcom.element.element.Element at 0x11cbae198>,
#  <gedcom.element.element.Element at 0x11cbae588>,
#  <gedcom.element.element.Element at 0x11cbae978>,
#  <gedcom.element.element.Element at 0x11cbaed68>,
#  <gedcom.element.element.Element at 0x11cbb0198>,
#  <gedcom.element.element.Element at 0x11cbb0588>,
#  <gedcom.element.element.Element at 0x11cbb0978>,
#  <gedcom.element.element.Element at 0x11cbb0c18>,
#  <gedcom.element.element.Element at 0x11cbb3048>,
#  <gedcom.element.element.Element at 0x11cbb3438>,
#  <gedcom.element.element.Element at 0x11cbb3828>,
#  <gedcom.element.element.Element at 0x11cbb3c18>,
#  <gedcom.element.element.Element at 0x11cbb5048>,
#  <gedcom.element.element.Element at 0x11cbb5438>,
#  <gedcom.element.element.Element at 0x11cbb5828>,
#  <gedcom.element.element.Element at 0x11cbb5c18>,
#  <gedcom.element.element.Element at 0x11cbb8048>,
#  <gedcom.element.element.Element at 0x11cbb8438>,
#  <gedcom.element.element.Element at 0x11cbb8828>,
#  <gedcom.element.element.Element at 0x11cbb8c18>,
#  <gedcom.element.element.Element at 0x11cbbc048>,
#  <gedcom.element.element.Element at 0x11cbbc438>,
#  <gedcom.element.element.Element at 0x11cbbc828>,
#  <gedcom.element.element.Element at 0x11cbbcc18>,
#  <gedcom.element.element.Element at 0x11cbbd048>,
#  <gedcom.element.element.Element at 0x11cbbd438>,
#  <gedcom.element.element.Element at 0x11cbbd828>,
#  <gedcom.element.element.Element at 0x11cbbdc18>,
#  <gedcom.element.element.Element at 0x11cbc1048>,
#  <gedcom.element.element.Element at 0x11cbc1438>,
#  <gedcom.element.element.Element at 0x11cbc1828>,
#  <gedcom.element.element.Element at 0x11cbc1c18>,
#  <gedcom.element.element.Element at 0x11cbc3048>,
#  <gedcom.element.element.Element at 0x11cbc3438>,
#  <gedcom.element.element.Element at 0x11cbc3828>,
#  <gedcom.element.element.Element at 0x11cbc3c18>,
#  <gedcom.element.element.Element at 0x11cbc6048>,
#  <gedcom.element.element.Element at 0x11cbc6438>,
#  <gedcom.element.element.Element at 0x11cbc6828>,
#  <gedcom.element.element.Element at 0x11cbc6c18>,
#  <gedcom.element.element.Element at 0x11cbc9048>,
#  <gedcom.element.element.Element at 0x11cbc9438>,
#  <gedcom.element.element.Element at 0x11cbc9828>,
#  <gedcom.element.element.Element at 0x11cbc9c18>,
#  <gedcom.element.element.Element at 0x11cbcc048>,
#  <gedcom.element.element.Element at 0x11cbcc438>,
#  <gedcom.element.element.Element at 0x11cbcc828>,
#  <gedcom.element.element.Element at 0x11cbccc18>,
#  <gedcom.element.element.Element at 0x11cbcf080>,
#  <gedcom.element.element.Element at 0x11cbcf470>,
#  <gedcom.element.element.Element at 0x11cbcf860>,
#  <gedcom.element.element.Element at 0x11cbcfc50>,
#  <gedcom.element.element.Element at 0x11cbd1080>,
#  <gedcom.element.element.Element at 0x11cbd1470>,
#  <gedcom.element.element.Element at 0x11cbd1860>,
#  <gedcom.element.element.Element at 0x11cbd1c50>,
#  <gedcom.element.element.Element at 0x11cbd6080>,
#  <gedcom.element.element.Element at 0x11cbd6470>,
#  <gedcom.element.element.Element at 0x11cbd6860>,
#  <gedcom.element.element.Element at 0x11cbd6c50>,
#  <gedcom.element.element.Element at 0x11cbd8080>,
#  <gedcom.element.element.Element at 0x11cbd8470>,
#  <gedcom.element.element.Element at 0x11cbd8860>,
#  <gedcom.element.element.Element at 0x11cbd8c50>,
#  <gedcom.element.element.Element at 0x11cbdc080>,
#  <gedcom.element.element.Element at 0x11cbdc470>,
#  <gedcom.element.element.Element at 0x11cbdc860>,
#  <gedcom.element.element.Element at 0x11cbdcc50>,
#  <gedcom.element.element.Element at 0x11cbde128>,
#  <gedcom.element.element.Element at 0x11cbde518>,
#  <gedcom.element.element.Element at 0x11cbde908>,
#  <gedcom.element.element.Element at 0x11cbdecf8>,
#  <gedcom.element.element.Element at 0x11cbe01d0>,
#  <gedcom.element.element.Element at 0x11cbe05c0>,
#  <gedcom.element.element.Element at 0x11cbe09b0>,
#  <gedcom.element.element.Element at 0x11cbe0d68>]

# %%
#use empty list to collect data
data = []
# Iterate through all root child elements
for element in root_child_elements:

    # Is the `element` an actual `IndividualElement`? (Allows usage of extra functions such as `surname_match` and `get_name`.)
    if isinstance(element, IndividualElement):
        
        if element.is_individual:
            INDI = element.get_pointer()
            (first, last) = element.get_name()
            sex = element.get_gender()
            DOB_simple = element.get_birth_year()
            DOD_simple = element.get_death_year()
            #ancestors = gedcom_parser.get_ancestors(element)
            parents = gedcom_parser.get_parents(element)
          #  if gedcom_parser.get_parents(element) is '[]':
           #     print("NaN")
        
            #DOB = element.get_birth_data()  ##this includes source info and full date
            #DOD = element.get_death_data()  ##ditto  
            
            #append all at once so that it can go from list to DF
            data.append([first, last, sex, DOB_simple, DOD_simple, parents, INDI])

# %%
data
# Out:
# [['James Garrett',
#   'Biddle',
#   'M',
#   1868,
#   1947,
#   [<gedcom.element.individual.IndividualElement at 0x11c8514a8>,
#    <gedcom.element.individual.IndividualElement at 0x11c8466d8>],
#   '@P1@'],
#  ['Mary',
#   'Hutton',
#   'F',
#   1869,
#   1925,
#   [<gedcom.element.individual.IndividualElement at 0x10a5078d0>,
#    <gedcom.element.individual.IndividualElement at 0x10a4f8b00>],
#   '@P2@'],
#  ['Mary',
#   'Hewes',
#   'F',
#   1842,
#   1874,
#   [<gedcom.element.individual.IndividualElement at 0x10a51b8d0>,
#    <gedcom.element.individual.IndividualElement at 0x10a51aef0>],
#   '@P3@'],
#  ['John William',
#   'Biddle',
#   'M',
#   1835,
#   1916,
#   [<gedcom.element.individual.IndividualElement at 0x10a4f04e0>,
#    <gedcom.element.individual.IndividualElement at 0x10a4f2400>],
#   '@P4@'],
#  ['Addison Hutton',
#   'Biddle',
#   'M',
#   1903,
#   1912,
#   [<gedcom.element.individual.IndividualElement at 0x11c821c50>,
#    <gedcom.element.individual.IndividualElement at 0x11c8379e8>],
#   '@P5@'],
#  ['Ruth',
#   'Biddle',
#   'F',
#   1906,
#   1969,
#   [<gedcom.element.individual.IndividualElement at 0x11c821c50>,
#    <gedcom.element.individual.IndividualElement at 0x11c8379e8>],
#   '@P6@'],
#  ['Rebecca Hutton',
#   'Biddle',
#   'F',
#   1901,
#   1991,
#   [<gedcom.element.individual.IndividualElement at 0x11c821c50>,
#    <gedcom.element.individual.IndividualElement at 0x11c8379e8>],
#   '@P7@'],
#  ['Elizabeth Rebecca',
#   'Biddle',
#   'F',
#   1897,
#   1975,
#   [<gedcom.element.individual.IndividualElement at 0x11c821c50>,
#    <gedcom.element.individual.IndividualElement at 0x11c8379e8>],
#   '@P8@'],
#  ['Dorothy',
#   'Biddle',
#   'F',
#   1900,
#   1985,
#   [<gedcom.element.individual.IndividualElement at 0x11c821c50>,
#    <gedcom.element.individual.IndividualElement at 0x11c8379e8>],
#   '@P9@'],
#  ['Mary Hewes',
#   'Biddle',
#   'F',
#   1898,
#   1963,
#   [<gedcom.element.individual.IndividualElement at 0x11c821c50>,
#    <gedcom.element.individual.IndividualElement at 0x11c8379e8>],
#   '@P10@'],
#  ['Ruth Ella', 'Chambers', 'F', 1870, 1948, [], '@P11@'],
#  ['William', 'Biddle', 'M', 1806, 1887, [], '@P12@'],
#  ['Elizabeth Cesson', 'Biddle', 'F', -1, 1881, [], '@P13@'],
#  ['William',
#   'Biddle',
#   'M',
#   1863,
#   1948,
#   [<gedcom.element.individual.IndividualElement at 0x11c8514a8>,
#    <gedcom.element.individual.IndividualElement at 0x11c8466d8>],
#   '@P14@'],
#  ['Rebecca', 'Savery', 'F', 1836, 1902, [], '@P15@'],
#  ['Addison',
#   'Hutton',
#   'M',
#   1834,
#   1916,
#   [<gedcom.element.individual.IndividualElement at 0x11c93d2e8>,
#    <gedcom.element.individual.IndividualElement at 0x11c943dd8>],
#   '@P16@'],
#  ['Sarah S', 'Garrett', 'F', 1819, 1853, [], '@P17@'],
#  ['Edward C', 'Hewes', 'M', 1821, 1880, [], '@P18@'],
#  ['Margaret Cope',
#   'James',
#   'F',
#   1935,
#   1979,
#   [<gedcom.element.individual.IndividualElement at 0x10a545d68>,
#    <gedcom.element.individual.IndividualElement at 0x11c8b7f98>],
#   '@P19@'],
#  ['Caroline Biddle',
#   'James',
#   'F',
#   1932,
#   2012,
#   [<gedcom.element.individual.IndividualElement at 0x10a545d68>,
#    <gedcom.element.individual.IndividualElement at 0x11c8b7f98>],
#   '@P20@'],
#  ['Mary Hutton',
#   'James',
#   'F',
#   1930,
#   2002,
#   [<gedcom.element.individual.IndividualElement at 0x10a545d68>,
#    <gedcom.element.individual.IndividualElement at 0x11c8b7f98>],
#   '@P21@'],
#  ['John Robert',
#   'James',
#   'M',
#   1938,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10a545d68>,
#    <gedcom.element.individual.IndividualElement at 0x11c8b7f98>],
#   '@P22@'],
#  ['John Robert',
#   'James',
#   'M',
#   1895,
#   1992,
#   [<gedcom.element.individual.IndividualElement at 0x11c9b62b0>,
#    <gedcom.element.individual.IndividualElement at 0x11c9bc908>],
#   '@P23@'],
#  ['James Biddle',
#   'Yarnall',
#   'M',
#   1926,
#   2009,
#   [<gedcom.element.individual.IndividualElement at 0x10c2a8f60>,
#    <gedcom.element.individual.IndividualElement at 0x11c8a1898>],
#   '@P24@'],
#  ['Nancy Hutton',
#   'Yarnall',
#   'F',
#   1928,
#   2004,
#   [<gedcom.element.individual.IndividualElement at 0x10c2a8f60>,
#    <gedcom.element.individual.IndividualElement at 0x11c8a1898>],
#   '@P25@'],
#  ['David Robert',
#   'Yarnall',
#   'M',
#   1925,
#   1999,
#   [<gedcom.element.individual.IndividualElement at 0x10c2a8f60>,
#    <gedcom.element.individual.IndividualElement at 0x11c8a1898>],
#   '@P26@'],
#  ['David Robert',
#   'Yarnall',
#   'M',
#   1878,
#   1967,
#   [<gedcom.element.individual.IndividualElement at 0x11c94f2b0>,
#    <gedcom.element.individual.IndividualElement at 0x11c94a588>],
#   '@P27@'],
#  ['David Macowan',
#   'Sinclair',
#   'M',
#   1928,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c2ea908>,
#    <gedcom.element.individual.IndividualElement at 0x10a4daa58>],
#   '@P28@'],
#  ['Sylvia Buell',
#   'Sinclair',
#   'F',
#   1929,
#   2015,
#   [<gedcom.element.individual.IndividualElement at 0x10c2ea908>,
#    <gedcom.element.individual.IndividualElement at 0x10a4daa58>],
#   '@P29@'],
#  ['Mary Biddle',
#   'Sinclair',
#   'F',
#   1926,
#   2009,
#   [<gedcom.element.individual.IndividualElement at 0x10c2ea908>,
#    <gedcom.element.individual.IndividualElement at 0x10a4daa58>],
#   '@P30@'],
#  ['John Biddle',
#   'Sinclair',
#   'M',
#   1935,
#   2019,
#   [<gedcom.element.individual.IndividualElement at 0x10c2ea908>,
#    <gedcom.element.individual.IndividualElement at 0x10a4daa58>],
#   '@P31@'],
#  ['John Stephens',
#   'Sinclair',
#   'M',
#   1897,
#   1972,
#   [<gedcom.element.individual.IndividualElement at 0x11c968b38>,
#    <gedcom.element.individual.IndividualElement at 0x11c9610f0>],
#   '@P32@'],
#  ['Cecilia',
#   'Bradbeer',
#   'F',
#   1930,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c8f7898>,
#    <gedcom.element.individual.IndividualElement at 0x11c888630>],
#   '@P33@'],
#  ['James Biddle',
#   'Bradbeer',
#   'M',
#   1932,
#   2019,
#   [<gedcom.element.individual.IndividualElement at 0x11c8f7898>,
#    <gedcom.element.individual.IndividualElement at 0x11c888630>],
#   '@P34@'],
#  ['Frank Gilbert',
#   'Bradbeer',
#   'M',
#   1887,
#   1935,
#   [<gedcom.element.individual.IndividualElement at 0x11ca3f8d0>,
#    <gedcom.element.individual.IndividualElement at 0x11ca39668>],
#   '@P35@'],
#  ['Thornton Bancroft',
#   'Penfield',
#   'M',
#   1934,
#   2007,
#   [<gedcom.element.individual.IndividualElement at 0x11c9235f8>,
#    <gedcom.element.individual.IndividualElement at 0x11c86c390>],
#   '@P36@'],
#  ['Charlotte Elizabeth',
#   'Penfield',
#   'F',
#   1935,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9235f8>,
#    <gedcom.element.individual.IndividualElement at 0x11c86c390>],
#   '@P37@'],
#  ['Thornton Bancroft',
#   'Penfield',
#   'M',
#   1899,
#   1975,
#   [<gedcom.element.individual.IndividualElement at 0x11ca24908>,
#    <gedcom.element.individual.IndividualElement at 0x11ca1f6a0>],
#   '@P38@'],
#  ['Joel Wright', 'Hutton', 'M', 1811, 1862, [], '@P39@'],
#  ['Ann', 'Mains', 'F', 1812, 1865, [], '@P40@'],
#  ['Sidney S', 'Garrett', 'F', 1851, 1949, [], '@P41@'],
#  ['Edward Smedley', 'Yarnall', 'M', 1846, 1931, [], '@P42@'],
#  ['Kristina Garrett',
#   'Yarnall',
#   'F',
#   1960,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11bc8aa20>,
#    <gedcom.element.individual.IndividualElement at 0x11c958518>],
#   '@P43@'],
#  ['Sara Gabrielsen',
#   'Yarnall',
#   'F',
#   1958,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11bc8aa20>,
#    <gedcom.element.individual.IndividualElement at 0x11c958518>],
#   '@P44@'],
#  ['Joan Biddle',
#   'Yarnall',
#   'F',
#   1956,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11bc8aa20>,
#    <gedcom.element.individual.IndividualElement at 0x11c958518>],
#   '@P45@'],
#  ['Rie',
#   'Gabrielsen',
#   'F',
#   1930,
#   1980,
#   [<gedcom.element.individual.IndividualElement at 0x11ca97da0>],
#   '@P46@'],
#  ['Stephen Garrett',
#   'Yarnall',
#   'M',
#   1957,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c29e358>,
#    <gedcom.element.individual.IndividualElement at 0x11c95f710>],
#   '@P47@'],
#  ['James Biddle',
#   'Yarnall',
#   'M',
#   1955,
#   2018,
#   [<gedcom.element.individual.IndividualElement at 0x10c29e358>,
#    <gedcom.element.individual.IndividualElement at 0x11c95f710>],
#   '@P48@'],
#  ['Phyllis A.', 'Aspen', 'F', 1929, 2013, [], '@P49@'],
#  ['Alice Elvira', 'Stephens', 'F', 1861, 1933, [], '@P50@'],
#  ['David MaCowan', 'Sinclair', 'M', 1861, 1935, [], '@P51@'],
#  ['Mary Hewes',
#   'Buck',
#   'F',
#   1955,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c982d68>,
#    <gedcom.element.individual.IndividualElement at 0x10c2d7828>],
#   '@P52@'],
#  ['Alice Sinclair',
#   'Buck',
#   'F',
#   1953,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c982d68>,
#    <gedcom.element.individual.IndividualElement at 0x10c2d7828>],
#   '@P53@'],
#  ['David Douglass',
#   'Buck',
#   'M',
#   1949,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c982d68>,
#    <gedcom.element.individual.IndividualElement at 0x10c2d7828>],
#   '@P54@'],
#  ['John Clayton',
#   'Buck',
#   'M',
#   1950,
#   2009,
#   [<gedcom.element.individual.IndividualElement at 0x11c982d68>,
#    <gedcom.element.individual.IndividualElement at 0x10c2d7828>],
#   '@P55@'],
#  ['Joseph J.', 'Krakora', 'M', 1939, -1, [], '@P56@'],
#  ['Clayton Douglass',
#   'Buck',
#   'M',
#   1923,
#   1986,
#   [<gedcom.element.individual.IndividualElement at 0x11ca117b8>,
#    <gedcom.element.individual.IndividualElement at 0x11ca0bac8>],
#   '@P57@'],
#  ['John Christopher',
#   'Carr',
#   'M',
#   1966,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9aa550>,
#    <gedcom.element.individual.IndividualElement at 0x10c2c9358>],
#   '@P58@'],
#  ['Elizabeth Anne',
#   'Carr',
#   'F',
#   1964,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9aa550>,
#    <gedcom.element.individual.IndividualElement at 0x10c2c9358>],
#   '@P59@'],
#  ['Daniel Thaddeus',
#   'Carr',
#   'M',
#   1963,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9aa550>,
#    <gedcom.element.individual.IndividualElement at 0x10c2c9358>],
#   '@P60@'],
#  ['Suzanne Noel',
#   'Carr',
#   'F',
#   1960,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9aa550>,
#    <gedcom.element.individual.IndividualElement at 0x10c2c9358>],
#   '@P61@'],
#  ['Matthew Francis',
#   'Carr',
#   'M',
#   1958,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9aa550>,
#    <gedcom.element.individual.IndividualElement at 0x10c2c9358>],
#   '@P62@'],
#  ['Deborah Ward',
#   'Carr',
#   'F',
#   1957,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9aa550>,
#    <gedcom.element.individual.IndividualElement at 0x10c2c9358>],
#   '@P63@'],
#  ['Sylvia Stephens',
#   'Carr',
#   'F',
#   1956,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9aa550>,
#    <gedcom.element.individual.IndividualElement at 0x10c2c9358>],
#   '@P64@'],
#  ['Stephen Kerry',
#   'Carr',
#   'M',
#   1955,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9aa550>,
#    <gedcom.element.individual.IndividualElement at 0x10c2c9358>],
#   '@P65@'],
#  ['Kathleen Mary',
#   'Carr',
#   'F',
#   1954,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9aa550>,
#    <gedcom.element.individual.IndividualElement at 0x10c2c9358>],
#   '@P66@'],
#  ['Stephen Kerry', 'Carr', 'M', 1930, -1, [], '@P67@'],
#  ['Milo', 'Berking', '', 1925, 2007, [], '@P68@'],
#  ['John Edwin', 'James', 'M', 1864, 1938, [], '@P69@'],
#  ['Mary Hughes', 'Cope', 'F', 1865, 1954, [], '@P70@'],
#  ['Janet Biddle',
#   'Herrin',
#   'F',
#   1965,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9c2ba8>,
#    <gedcom.element.individual.IndividualElement at 0x10a526a58>],
#   '@P71@'],
#  ['Gareld Robertson', 'Herrin', 'M', 1929, 2005, [], '@P72@'],
#  ['Kenneth James',
#   'Herrin',
#   'M',
#   1962,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9c2ba8>,
#    <gedcom.element.individual.IndividualElement at 0x10a526a58>],
#   '@P73@'],
#  ['John Robertson',
#   'Herrin',
#   'M',
#   1960,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9c2ba8>,
#    <gedcom.element.individual.IndividualElement at 0x10a526a58>],
#   '@P74@'],
#  ['Mary Thayer',
#   'Herrin',
#   'F',
#   1958,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9c2ba8>,
#    <gedcom.element.individual.IndividualElement at 0x10a526a58>],
#   '@P75@'],
#  ['Frederic Valerius',
#   'Hetzel',
#   'M',
#   1930,
#   2005,
#   [<gedcom.element.individual.IndividualElement at 0x11cae78d0>,
#    <gedcom.element.individual.IndividualElement at 0x11cae7470>],
#   '@P76@'],
#  ['Sylvia Biddle',
#   'Hetzel',
#   'F',
#   1959,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9d1748>,
#    <gedcom.element.individual.IndividualElement at 0x10a531d68>],
#   '@P77@'],
#  ['Frederic James',
#   'Hetzel',
#   'M',
#   1957,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9d1748>,
#    <gedcom.element.individual.IndividualElement at 0x10a531d68>],
#   '@P78@'],
#  ['Robert Wills',
#   'Hetzel',
#   'M',
#   1954,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9d1748>,
#    <gedcom.element.individual.IndividualElement at 0x10a531d68>],
#   '@P79@'],
#  ['Elizabeth Barr',
#   'Holt',
#   'F',
#   1968,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9e4160>,
#    <gedcom.element.individual.IndividualElement at 0x10a51d2b0>],
#   '@P80@'],
#  ['John Harris',
#   'Holt',
#   'M',
#   1965,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9e4160>,
#    <gedcom.element.individual.IndividualElement at 0x10a51d2b0>],
#   '@P81@'],
#  ['Richard James',
#   'Holt',
#   'M',
#   1960,
#   1960,
#   [<gedcom.element.individual.IndividualElement at 0x11c9e4160>,
#    <gedcom.element.individual.IndividualElement at 0x10a51d2b0>],
#   '@P82@'],
#  ['Harris Richard',
#   'Holt',
#   'M',
#   1934,
#   2009,
#   [<gedcom.element.individual.IndividualElement at 0x11caffbe0>,
#    <gedcom.element.individual.IndividualElement at 0x11cafc5c0>],
#   '@P83@'],
#  ['Cynthia Biddle',
#   'Holt',
#   'F',
#   1962,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9e4160>,
#    <gedcom.element.individual.IndividualElement at 0x10a51d2b0>],
#   '@P84@'],
#  ['Margot',
#   'Sinclair',
#   'F',
#   1962,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c2bd470>,
#    <gedcom.element.individual.IndividualElement at 0x11c9faef0>],
#   '@P85@'],
#  ['Craig Widmann',
#   'Sinclair',
#   'M',
#   1959,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c2bd470>,
#    <gedcom.element.individual.IndividualElement at 0x11c9faef0>],
#   '@P86@'],
#  ['Timothy Biddle',
#   'Sinclair',
#   'M',
#   1958,
#   1968,
#   [<gedcom.element.individual.IndividualElement at 0x10c2bd470>,
#    <gedcom.element.individual.IndividualElement at 0x11c9faef0>],
#   '@P87@'],
#  ['Susan', 'Widmann', 'F', 1932, -1, [], '@P88@'],
#  ['Anne Zeis',
#   'Sinclair',
#   'F',
#   1965,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c2e4be0>,
#    <gedcom.element.individual.IndividualElement at 0x11ca05fd0>],
#   '@P89@'],
#  ['David Rickards',
#   'Sinclair',
#   'M',
#   1962,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c2e4be0>,
#    <gedcom.element.individual.IndividualElement at 0x11ca05fd0>],
#   '@P90@'],
#  ['John Biddle',
#   'Sinclair',
#   'M',
#   1960,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c2e4be0>,
#    <gedcom.element.individual.IndividualElement at 0x11ca05fd0>],
#   '@P91@'],
#  ['Lynn', 'Rickards', 'F', 1935, -1, [], '@P92@'],
#  ['Alice Hounsfield', 'du Pont', 'F', 1891, 1967, [], '@P93@'],
#  ['Clayton Douglass', 'Buck', 'M', 1890, 1965, [], '@P94@'],
#  ['Jeremiah Clayton',
#   'Buck',
#   'M',
#   1978,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c97a9b0>,
#    <gedcom.element.individual.IndividualElement at 0x11ca16d68>],
#   '@P95@'],
#  ['Magnolia Hannah',
#   'Buck',
#   'F',
#   1975,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c97a9b0>,
#    <gedcom.element.individual.IndividualElement at 0x11ca16d68>],
#   '@P96@'],
#  ['Gayle Maureen', 'Hannah', 'F', 1954, -1, [], '@P97@'],
#  ['Kathryn Anne',
#   'Krakora',
#   'F',
#   1965,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c97de48>,
#    <gedcom.element.individual.IndividualElement at 0x11ca19a58>],
#   '@P98@'],
#  ['Diane Brace', 'Conner', 'F', 1938, -1, [], '@P99@'],
#  ['Leigh Biddle',
#   'James',
#   'F',
#   1980,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10a541240>,
#    <gedcom.element.individual.IndividualElement at 0x11ca1e588>],
#   '@P100@'],
#  ['Christina Ballard',
#   'James',
#   'F',
#   1978,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10a541240>,
#    <gedcom.element.individual.IndividualElement at 0x11ca1e588>],
#   '@P101@'],
#  ['Dixie Lee', 'Donaldson', 'F', 1945, -1, [], '@P102@'],
#  ['John Robert',
#   'James',
#   'M',
#   1974,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10a541240>,
#    <gedcom.element.individual.IndividualElement at 0x11ca1e588>],
#   '@P103@'],
#  ['Martha Mee', 'Martin', 'F', 1868, 1954, [], '@P104@'],
#  ['Thornton Bancroft', 'Penfield', 'M', 1867, 1958, [], '@P105@'],
#  ['Janet Richardson', 'German', 'F', 1916, 2004, [], '@P106@'],
#  ['Diane', 'Depp', '', 1947, -1, [], '@P107@'],
#  ['Elizabeth', 'Few', 'F', 1939, -1, [], '@P108@'],
#  ['Cecilia Henrietta', 'Jones', 'F', 1865, 1915, [], '@P109@'],
#  ['Frank', 'Bradbeer', 'M', 1865, 1898, [], '@P110@'],
#  ['Erica Maria Smit',
#   'Sibinga',
#   'F',
#   1962,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca4ba20>,
#    <gedcom.element.individual.IndividualElement at 0x10c3022e8>],
#   '@P111@'],
#  ['Nicholas Ernst Smit',
#   'Sibinga',
#   'M',
#   1959,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca4ba20>,
#    <gedcom.element.individual.IndividualElement at 0x10c3022e8>],
#   '@P112@'],
#  ['Derek Johannes Smit',
#   'Sibinga',
#   'M',
#   1961,
#   1961,
#   [<gedcom.element.individual.IndividualElement at 0x11ca4ba20>,
#    <gedcom.element.individual.IndividualElement at 0x10c3022e8>],
#   '@P113@'],
#  ['Michael Frank Smit',
#   'Sibinga',
#   'M',
#   1957,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca4ba20>,
#    <gedcom.element.individual.IndividualElement at 0x10c3022e8>],
#   '@P114@'],
#  ['Maarten', 'Sibinga', 'M', 1927, 2003, [], '@P115@'],
#  ['James Biddle',
#   'Bradbeer',
#   'M',
#   1962,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c8ea198>,
#    <gedcom.element.individual.IndividualElement at 0x11ca503c8>],
#   '@P116@'],
#  ['Mary Florence', 'Buckley', 'F', 1935, 1999, [], '@P117@'],
#  ['Rebecca Hutton',
#   'Bradbeer',
#   'U',
#   1966,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c8ea198>,
#    <gedcom.element.individual.IndividualElement at 0x11ca503c8>],
#   '@P118@'],
#  ['Arthur Edwin',
#   'James',
#   'M',
#   1897,
#   1989,
#   [<gedcom.element.individual.IndividualElement at 0x11c9b62b0>,
#    <gedcom.element.individual.IndividualElement at 0x11c9bc908>],
#   '@P119@'],
#  ['William Cope',
#   'James',
#   'M',
#   1893,
#   1960,
#   [<gedcom.element.individual.IndividualElement at 0x11c9b62b0>,
#    <gedcom.element.individual.IndividualElement at 0x11c9bc908>],
#   '@P120@'],
#  ['Margaret Sharpless',
#   'James',
#   'F',
#   1891,
#   1934,
#   [<gedcom.element.individual.IndividualElement at 0x11c9b62b0>,
#    <gedcom.element.individual.IndividualElement at 0x11c9bc908>],
#   '@P121@'],
#  ['Lauretta Phillips',
#   'James',
#   'F',
#   1890,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9b62b0>,
#    <gedcom.element.individual.IndividualElement at 0x11c9bc908>],
#   '@P122@'],
#  ['William',
#   'Sinclair',
#   'M',
#   1896,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c968b38>,
#    <gedcom.element.individual.IndividualElement at 0x11c9610f0>],
#   '@P123@'],
#  ['Sylvia',
#   'Sinclair',
#   'F',
#   1894,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c968b38>,
#    <gedcom.element.individual.IndividualElement at 0x11c9610f0>],
#   '@P124@'],
#  ['Jessie Cecilia',
#   'Bradbeer',
#   'F',
#   1893,
#   1979,
#   [<gedcom.element.individual.IndividualElement at 0x11ca3f8d0>,
#    <gedcom.element.individual.IndividualElement at 0x11ca39668>],
#   '@P125@'],
#  ['Albert Frederick',
#   'Bradbeer',
#   'M',
#   1890,
#   1963,
#   [<gedcom.element.individual.IndividualElement at 0x11ca3f8d0>,
#    <gedcom.element.individual.IndividualElement at 0x11ca39668>],
#   '@P126@'],
#  ['Paul Livingstone',
#   'Penfield',
#   'M',
#   1901,
#   1992,
#   [<gedcom.element.individual.IndividualElement at 0x11ca24908>,
#    <gedcom.element.individual.IndividualElement at 0x11ca1f6a0>],
#   '@P127@'],
#  ['Charlotte Martin',
#   'Penfield',
#   'F',
#   1895,
#   1979,
#   [<gedcom.element.individual.IndividualElement at 0x11ca24908>,
#    <gedcom.element.individual.IndividualElement at 0x11ca1f6a0>],
#   '@P128@'],
#  ['Winifred M',
#   'Atwater',
#   'F',
#   1881,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca24908>,
#    <gedcom.element.individual.IndividualElement at 0x11ca1f6a0>],
#   '@P129@'],
#  ['Rebecca Elizabeth',
#   'Gosselink',
#   'F',
#   1967,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca91dd8>,
#    <gedcom.element.individual.IndividualElement at 0x11c919c50>],
#   '@P130@'],
#  ['Robert George',
#   'Gosselink',
#   'M',
#   1964,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca91dd8>,
#    <gedcom.element.individual.IndividualElement at 0x11c919c50>],
#   '@P131@'],
#  ['James Bancroft',
#   'Gosselink',
#   'M',
#   1963,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca91dd8>,
#    <gedcom.element.individual.IndividualElement at 0x11c919c50>],
#   '@P132@'],
#  ['Charles George', 'Gosselink', 'M', 1935, -1, [], '@P133@'],
#  ['Hans', 'Gabrielsen', 'M', 1900, -1, [], '@P134@'],
#  ['Evan Robert',
#   'Ma',
#   'M',
#   1992,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca99eb8>,
#    <gedcom.element.individual.IndividualElement at 0x11c954e80>],
#   '@P135@'],
#  ['Rie Yarnall',
#   'Ma',
#   'F',
#   1987,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca99eb8>,
#    <gedcom.element.individual.IndividualElement at 0x11c954e80>],
#   '@P136@'],
#  ['Robert Tien', 'Ma', 'M', 1959, -1, [], '@P137@'],
#  ['Rachel Yarnall',
#   'Sanders',
#   'F',
#   1988,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca9bda0>,
#    <gedcom.element.individual.IndividualElement at 0x11c954940>],
#   '@P138@'],
#  ['Gabriel Yarnall',
#   'Sanders',
#   'M',
#   1985,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca9bda0>,
#    <gedcom.element.individual.IndividualElement at 0x11c954940>],
#   '@P139@'],
#  ['David Alan', 'Sanders', 'M', 1942, -1, [], '@P140@'],
#  ['Owen',
#   'Sibinga',
#   'M',
#   2005,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca44080>,
#    <gedcom.element.individual.IndividualElement at 0x11c952cc0>],
#   '@P141@'],
#  ['Tyche Eva',
#   'Sibinga',
#   'F',
#   1995,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca44080>,
#    <gedcom.element.individual.IndividualElement at 0x11c952cc0>],
#   '@P142@'],
#  ['James Garrett',
#   'Sibinga',
#   'M',
#   1991,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca44080>,
#    <gedcom.element.individual.IndividualElement at 0x11c952cc0>],
#   '@P143@'],
#  ['Nathaniel Alexander',
#   'Sibinga',
#   'M',
#   1989,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca44080>,
#    <gedcom.element.individual.IndividualElement at 0x11c952cc0>],
#   '@P144@'],
#  ['Dianne', 'DuBois', 'F', -1, -1, [], '@P145@'],
#  ['Elizabeth Claire',
#   'Yarnall',
#   'F',
#   2003,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c95a9b0>,
#    <gedcom.element.individual.IndividualElement at 0x11caa2b70>],
#   '@P146@'],
#  ['Rebecca Nicole',
#   'Yarnall',
#   'F',
#   2003,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c95a9b0>,
#    <gedcom.element.individual.IndividualElement at 0x11caa2b70>],
#   '@P147@'],
#  ['Sidney Paige',
#   'Yarnall',
#   'F',
#   2001,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c95a9b0>,
#    <gedcom.element.individual.IndividualElement at 0x11caa2b70>],
#   '@P148@'],
#  ['Elizabeth', 'Mapes', 'F', 1961, -1, [], '@P149@'],
#  ['Carly', 'Klapp', 'F', -1, -1, [], '@P150@'],
#  ['Kristine', 'Hill', 'F', -1, -1, [], '@P151@'],
#  ['Thomas Garrett',
#   'Buck',
#   'M',
#   1984,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c975a90>,
#    <gedcom.element.individual.IndividualElement at 0x11caa4b70>],
#   '@P152@'],
#  ['Nancy E.', 'Miller', 'F', 1954, -1, [], '@P153@'],
#  ['Thaddeus Chase',
#   'Buck',
#   'M',
#   1976,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c975a90>,
#    <gedcom.element.individual.IndividualElement at 0x11caa7940>],
#   '@P154@'],
#  ['Shelli I.', 'Chase', 'F', 1953, -1, [], '@P155@'],
#  ['John Garrett',
#   'DeCandia',
#   'M',
#   1989,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11caaab38>,
#    <gedcom.element.individual.IndividualElement at 0x11c975470>],
#   '@P156@'],
#  ['Michael Douglass',
#   'DeCandia',
#   'M',
#   1986,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11caaab38>,
#    <gedcom.element.individual.IndividualElement at 0x11c975470>],
#   '@P157@'],
#  ['Michael John', 'DeCandia', 'M', 1951, -1, [], '@P158@'],
#  ['David', 'Quint', 'M', -1, -1, [], '@P159@'],
#  ['Joseph Samuel',
#   'Buck',
#   'M',
#   1984,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11caac0b8>,
#    <gedcom.element.individual.IndividualElement at 0x11c9739b0>],
#   '@P160@'],
#  ['Ellie Mae',
#   'McDonald',
#   'F',
#   1979,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11caacc88>,
#    <gedcom.element.individual.IndividualElement at 0x11c9739b0>],
#   '@P161@'],
#  ['Glenn', 'McDonald', 'M', -1, -1, [], '@P162@'],
#  ['Lindy',
#   'Sinclair',
#   'F',
#   2000,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9f5400>,
#    <gedcom.element.individual.IndividualElement at 0x11caaf6d8>],
#   '@P163@'],
#  ['Nan M', 'Octeau', 'F', 1966, -1, [], '@P164@'],
#  ['Jason Andrew',
#   'Mannka',
#   'M',
#   1994,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cab4400>,
#    <gedcom.element.individual.IndividualElement at 0x11c9f1320>],
#   '@P165@'],
#  ['Christopher Scott',
#   'Mannka',
#   'M',
#   1994,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cab4400>,
#    <gedcom.element.individual.IndividualElement at 0x11c9f1320>],
#   '@P166@'],
#  ['Peter James',
#   'Mannka',
#   'M',
#   1991,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cab4400>,
#    <gedcom.element.individual.IndividualElement at 0x11c9f1320>],
#   '@P167@'],
#  ['Scott Daniel', 'Mannka', 'M', 1960, -1, [], '@P168@'],
#  ['Karl Bryn',
#   'Heavenrich',
#   'M',
#   1993,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11caba860>,
#    <gedcom.element.individual.IndividualElement at 0x11c9a6198>],
#   '@P169@'],
#  ['Jessica Anne',
#   'Heavenrich',
#   'F',
#   1990,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11caba860>,
#    <gedcom.element.individual.IndividualElement at 0x11c9a6198>],
#   '@P170@'],
#  ['Jeb Sinclair',
#   'Heavenrich',
#   'M',
#   1988,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11caba860>,
#    <gedcom.element.individual.IndividualElement at 0x11c9a6198>],
#   '@P171@'],
#  ['Walter', 'Heavenrich', 'M', 1951, -1, [], '@P172@'],
#  ['Debora', '', 'F', -1, -1, [], '@P173@'],
#  ['Brendan Connor',
#   'Carr',
#   'M',
#   1990,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9a1cc0>,
#    <gedcom.element.individual.IndividualElement at 0x11cac0710>],
#   '@P174@'],
#  ['Ryan Samuel',
#   'Carr',
#   'M',
#   1985,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9a1cc0>,
#    <gedcom.element.individual.IndividualElement at 0x11cac0710>],
#   '@P175@'],
#  ['Sean Kerry',
#   'Carr',
#   'M',
#   1983,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9a1cc0>,
#    <gedcom.element.individual.IndividualElement at 0x11cac0710>],
#   '@P176@'],
#  ['Kari Beth', 'Olson', 'F', 1956, -1, [], '@P177@'],
#  ['Emma Hewes',
#   'Rubenstein',
#   'F',
#   1991,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cac7320>,
#    <gedcom.element.individual.IndividualElement at 0x11c9a0908>],
#   '@P178@'],
#  ['Anne Chandler',
#   'Rubenstein',
#   'F',
#   1988,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cac7320>,
#    <gedcom.element.individual.IndividualElement at 0x11c9a0908>],
#   '@P179@'],
#  ['Katelyn Sinclair',
#   'Rubenstein',
#   'F',
#   1986,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cac7320>,
#    <gedcom.element.individual.IndividualElement at 0x11c9a0908>],
#   '@P180@'],
#  ['Donald Paul', 'Rubenstein', 'M', 1958, -1, [], '@P181@'],
#  ['William Ward',
#   'Adamy',
#   'M',
#   1990,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cacdb38>,
#    <gedcom.element.individual.IndividualElement at 0x11c99d9e8>],
#   '@P182@'],
#  ['Julia Sinclair',
#   'Adamy',
#   'F',
#   1988,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cacdb38>,
#    <gedcom.element.individual.IndividualElement at 0x11c99d9e8>],
#   '@P183@'],
#  ['Paul Kendrick', 'Adamy', 'M', 1957, -1, [], '@P184@'],
#  ['Hillary Hayes',
#   'Carr',
#   'F',
#   1991,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c99b978>,
#    <gedcom.element.individual.IndividualElement at 0x11cad0cf8>],
#   '@P185@'],
#  ['Ian Collins',
#   'Carr',
#   'M',
#   1988,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c99b978>,
#    <gedcom.element.individual.IndividualElement at 0x11cad0cf8>],
#   '@P186@'],
#  ['Matthew Francis',
#   'Carr',
#   'M',
#   1986,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c99b978>,
#    <gedcom.element.individual.IndividualElement at 0x11cad0cf8>],
#   '@P187@'],
#  ['Melissa', 'Golder', 'F', 1960, -1, [], '@P188@'],
#  ['Hannah Sinclair',
#   'Weber',
#   'F',
#   1996,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cad1a58>,
#    <gedcom.element.individual.IndividualElement at 0x11c998208>],
#   '@P189@'],
#  ['Sarah Noel',
#   'Weber',
#   'F',
#   1994,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cad1a58>,
#    <gedcom.element.individual.IndividualElement at 0x11c998208>],
#   '@P190@'],
#  ['Christian Dietrich', 'Weber', 'M', 1964, -1, [], '@P191@'],
#  ['Kirsti Lynn',
#   'Carr',
#   'F',
#   1996,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c996390>,
#    <gedcom.element.individual.IndividualElement at 0x11cad6470>],
#   '@P192@'],
#  ['Siri Marie',
#   'Carr',
#   'F',
#   1993,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c996390>,
#    <gedcom.element.individual.IndividualElement at 0x11cad6470>],
#   '@P193@'],
#  ['Kari Ellen', 'Kaalstad', 'F', 1963, -1, [], '@P194@'],
#  ['Sopia Elizabeth',
#   'Gennusa',
#   'F',
#   2003,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cad91d0>,
#    <gedcom.element.individual.IndividualElement at 0x11c994518>],
#   '@P195@'],
#  ['Robert Thomas', 'Riley', 'M', 1962, -1, [], '@P196@'],
#  ['Domenick', 'Gennusa', 'M', 1973, -1, [], '@P197@'],
#  ['Mary Sylvia',
#   'Carr',
#   'F',
#   2007,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c990320>,
#    <gedcom.element.individual.IndividualElement at 0x11cadc908>],
#   '@P198@'],
#  ['Lila Jane',
#   'Carr',
#   'F',
#   2003,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c990320>,
#    <gedcom.element.individual.IndividualElement at 0x11cadc908>],
#   '@P199@'],
#  ['Stephen Erikson',
#   'Carr',
#   'M',
#   2001,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c990320>,
#    <gedcom.element.individual.IndividualElement at 0x11cadc908>],
#   '@P200@'],
#  ['Abigail Josephine', 'Gouverneur', 'F', 1960, -1, [], '@P201@'],
#  ['Sarah Elizabeth', 'Fisher', 'F', 1966, -1, [], '@P202@'],
#  ['Elizabeth Smith',
#   'Sinclair',
#   'F',
#   1997,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca046d8>,
#    <gedcom.element.individual.IndividualElement at 0x11cae12e8>],
#   '@P203@'],
#  ['John Biddle',
#   'Sinclair',
#   'M',
#   1995,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca046d8>,
#    <gedcom.element.individual.IndividualElement at 0x11cae12e8>],
#   '@P204@'],
#  ['Karen', 'Smith', 'F', 1961, -1, [], '@P205@'],
#  ['Barbara', 'Hartmann', 'F', -1, -1, [], '@P206@'],
#  ['Ian Rickards',
#   'Sinclair',
#   'M',
#   1993,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca01908>,
#    <gedcom.element.individual.IndividualElement at 0x11cae4c50>],
#   '@P207@'],
#  ['Emily Hutton',
#   'Sinclair',
#   'F',
#   1991,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca01908>,
#    <gedcom.element.individual.IndividualElement at 0x11cae4c50>],
#   '@P208@'],
#  ['Peggy', 'Soder', 'F', 1963, -1, [], '@P209@'],
#  ['Ada Marie',
#   'Sinclair',
#   'F',
#   -1,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cae42b0>,
#    <gedcom.element.individual.IndividualElement at 0x11cae6400>],
#   '@P210@'],
#  ['Elizabeth', '', 'F', -1, -1, [], '@P211@'],
#  ['Adalynn Zeis',
#   'Griesser',
#   'F',
#   2000,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cae6fd0>,
#    <gedcom.element.individual.IndividualElement at 0x11c9ff828>],
#   '@P212@'],
#  ['Johan Patrick',
#   'Griesser',
#   'M',
#   1998,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cae6fd0>,
#    <gedcom.element.individual.IndividualElement at 0x11c9ff828>],
#   '@P213@'],
#  ['Hans Patrick', 'Griesser', 'M', 1961, -1, [], '@P214@'],
#  ['Rebecca Louise', 'Wills', 'F', -1, -1, [], '@P215@'],
#  ['Theodore Brinton', 'Hetzel', 'M', -1, -1, [], '@P216@'],
#  ['Skyler Krieg',
#   'Graham',
#   'M',
#   1994,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9dae80>,
#    <gedcom.element.individual.IndividualElement at 0x11caea710>],
#   '@P217@'],
#  ['Gavin Graham',
#   'Hetzel',
#   'M',
#   2002,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9dae80>,
#    <gedcom.element.individual.IndividualElement at 0x11caea710>],
#   '@P218@'],
#  ['Judy', 'Graham', 'F', 1970, -1, [], '@P219@'],
#  ['Benjamin Will',
#   'Hetzel',
#   'M',
#   1993,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9dae80>,
#    <gedcom.element.individual.IndividualElement at 0x11caec240>],
#   '@P220@'],
#  ['Laura Katherine', 'Tyree', 'F', 1965, -1, [], '@P221@'],
#  ['Ronda Leigh', 'Porter', 'F', 1955, -1, [], '@P222@'],
#  ['Andrea',
#   'Cipparrone',
#   'M',
#   1990,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11caef550>,
#    <gedcom.element.individual.IndividualElement at 0x11c9d49e8>],
#   '@P223@'],
#  ['Giacomo',
#   'Cipparrone',
#   'M',
#   1988,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11caef550>,
#    <gedcom.element.individual.IndividualElement at 0x11c9d49e8>],
#   '@P224@'],
#  ['Salvatore', 'Cipparrone', 'M', 1946, -1, [], '@P225@'],
#  ['Meaghan Caroline',
#   'McCarthy',
#   'F',
#   1997,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11caf1a90>,
#    <gedcom.element.individual.IndividualElement at 0x11c9cf470>],
#   '@P226@'],
#  ['Eric James',
#   'McCarthy',
#   'M',
#   1993,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11caf1a90>,
#    <gedcom.element.individual.IndividualElement at 0x11c9cf470>],
#   '@P227@'],
#  ['Matthew Ryan',
#   'McCarthy',
#   'M',
#   1991,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11caf1a90>,
#    <gedcom.element.individual.IndividualElement at 0x11c9cf470>],
#   '@P228@'],
#  ['David Michael', 'McCarthy', 'M', 1954, -1, [], '@P229@'],
#  ['Laura Anne',
#   'Herrin',
#   'F',
#   1992,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9ca278>,
#    <gedcom.element.individual.IndividualElement at 0x11caf4f60>],
#   '@P230@'],
#  ['Andrea Love',
#   'Herrin',
#   'F',
#   1986,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9ca278>,
#    <gedcom.element.individual.IndividualElement at 0x11caf4f60>],
#   '@P231@'],
#  ['Lisa', 'Baron', 'F', 1985, -1, [], '@P232@'],
#  ['Deborah Love', 'Morin', 'F', 1954, -1, [], '@P233@'],
#  ['Aimee Renee', 'Allen', 'F', 1965, -1, [], '@P234@'],
#  ['Reilly Caroline',
#   'Smith',
#   'F',
#   2016,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11caf8ba8>,
#    <gedcom.element.individual.IndividualElement at 0x11caf4518>],
#   '@P235@'],
#  ['Justin', 'Smith', 'M', -1, -1, [], '@P236@'],
#  ['Eirwen Jane',
#   'Cook',
#   'F',
#   2019,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cafb358>,
#    <gedcom.element.individual.IndividualElement at 0x11caf1f98>],
#   '@P237@'],
#  ['Joshua', 'Cook', 'M', -1, -1, [], '@P238@'],
#  ['Etta Hutton',
#   'Partridge',
#   'F',
#   2002,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cafc0b8>,
#    <gedcom.element.individual.IndividualElement at 0x11c9c2080>],
#   '@P239@'],
#  ['Garrett Robertson',
#   'Partridge',
#   'M',
#   2000,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cafc0b8>,
#    <gedcom.element.individual.IndividualElement at 0x11c9c2080>],
#   '@P240@'],
#  ['Stephen Michael', 'Partridge', 'M', 1962, -1, [], '@P241@'],
#  ['Anne Rosemary', 'Barr', 'F', 1907, 1979, [], '@P242@'],
#  ['Harris Bronston', 'Holt', 'M', 1908, 1971, [], '@P243@'],
#  ['Amanda Moore',
#   'Favret',
#   'F',
#   1992,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cb05d30>,
#    <gedcom.element.individual.IndividualElement at 0x11c9ec780>],
#   '@P244@'],
#  ['Rebecca Margaret',
#   'Favret',
#   'F',
#   1989,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cb05d30>,
#    <gedcom.element.individual.IndividualElement at 0x11c9ec780>],
#   '@P245@'],
#  ['Martin Augustine', 'Favret', 'U', 1962, -1, [], '@P246@'],
#  ['Ellen',
#   'Holt',
#   'F',
#   1937,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11caffbe0>,
#    <gedcom.element.individual.IndividualElement at 0x11cafc5c0>],
#   '@P247@'],
#  ['Ann-Lew Twyman',
#   'Holt',
#   'F',
#   1949,
#   2016,
#   [<gedcom.element.individual.IndividualElement at 0x11caffbe0>,
#    <gedcom.element.individual.IndividualElement at 0x11cafc5c0>],
#   '@P248@'],
#  ['Jean Chrisophe',
#   'Perez',
#   'M',
#   2007,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9e11d0>,
#    <gedcom.element.individual.IndividualElement at 0x11cb0e208>],
#   '@P249@'],
#  ['Sarah Biddle',
#   'Holt',
#   'F',
#   2008,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9e11d0>,
#    <gedcom.element.individual.IndividualElement at 0x11cb0e208>],
#   '@P250@'],
#  ['Garrett James',
#   'Holt',
#   'M',
#   2006,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11c9e11d0>,
#    <gedcom.element.individual.IndividualElement at 0x11cb0e208>],
#   '@P251@'],
#  ['Mary', "O'Hagin", 'F', 1973, -1, [], '@P252@'],
#  ['Margaret Rose',
#   'Titcomb',
#   'F',
#   2001,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cb0ecf8>,
#    <gedcom.element.individual.IndividualElement at 0x11c9df198>],
#   '@P253@'],
#  ['Timothy Douglas', 'Titcomb', 'M', 1958, -1, [], '@P254@'],
#  ['Hadleigh Parker',
#   'James',
#   'F',
#   2011,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca1ec88>,
#    <gedcom.element.individual.IndividualElement at 0x11cb13390>],
#   '@P255@'],
#  ['Addison  Ruth',
#   'James',
#   'F',
#   2009,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca1ec88>,
#    <gedcom.element.individual.IndividualElement at 0x11cb13390>],
#   '@P256@'],
#  ['Faith Jordan', 'Peters', 'F', 1978, -1, [], '@P257@'],
#  ['Alexander',
#   'Castanos',
#   'M',
#   2016,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cb16160>,
#    <gedcom.element.individual.IndividualElement at 0x11ca1a470>],
#   '@P258@'],
#  ['Ryan Michael', 'Castanos', 'M', 1982, -1, [], '@P259@'],
#  ['Derek Alan',
#   'Sibinga',
#   'M',
#   1997,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca49b38>,
#    <gedcom.element.individual.IndividualElement at 0x11cb16f28>],
#   '@P260@'],
#  ['Rebecca Mary',
#   'Sibinga',
#   'F',
#   1993,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca49b38>,
#    <gedcom.element.individual.IndividualElement at 0x11cb16f28>],
#   '@P261@'],
#  ['Mariann', 'Davis', 'F', 1964, -1, [], '@P262@'],
#  ['Dora Marie Sibinga',
#   'Hilker',
#   'F',
#   2001,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cb178d0>,
#    <gedcom.element.individual.IndividualElement at 0x11ca41b00>],
#   '@P263@'],
#  ['Kenneth John', 'Hilker', 'M', 1966, -1, [], '@P264@'],
#  ['Gale',
#   'Gosselink',
#   'F',
#   1989,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca8ed30>,
#    <gedcom.element.individual.IndividualElement at 0x11cb1b748>],
#   '@P265@'],
#  ['Janea Kelly',
#   'Gosselink',
#   'F',
#   1991,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca8ed30>,
#    <gedcom.element.individual.IndividualElement at 0x11cb1b748>],
#   '@P266@'],
#  ['Mary Elizabeth', 'Ward', 'F', 1964, -1, [], '@P267@'],
#  ['Ricardo',
#   'Gosselink',
#   'M',
#   1989,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca8ed30>,
#    <gedcom.element.individual.IndividualElement at 0x11cb1b748>],
#   '@P268@'],
#  ['Gordon',
#   'Gosselink',
#   'M',
#   1987,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca8ed30>,
#    <gedcom.element.individual.IndividualElement at 0x11cb1b748>],
#   '@P269@'],
#  ['Katherine Elizabeth',
#   'Johannes',
#   'F',
#   1998,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11cb1ca20>,
#    <gedcom.element.individual.IndividualElement at 0x11ca8cf98>],
#   '@P270@'],
#  ['Robert Alan', 'Johannes', 'M', 1962, -1, [], '@P271@'],
#  ['John Addison',
#   'Bradbeer',
#   'M',
#   2003,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca4e2b0>,
#    <gedcom.element.individual.IndividualElement at 0x11cb21080>],
#   '@P272@'],
#  ['Thomas Hutton',
#   'Bradbeer',
#   'M',
#   2000,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca4e2b0>,
#    <gedcom.element.individual.IndividualElement at 0x11cb21080>],
#   '@P273@'],
#  ['Peter Quinney',
#   'Bradbeer',
#   'M',
#   1998,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca4e2b0>,
#    <gedcom.element.individual.IndividualElement at 0x11cb21080>],
#   '@P274@'],
#  ['James Biddle',
#   'Bradbeer',
#   'M',
#   1996,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x11ca4e2b0>,
#    <gedcom.element.individual.IndividualElement at 0x11cb21080>],
#   '@P275@'],
#  ['Carol Elizabeth', 'Hastings', 'F', -1, -1, [], '@P276@']]

# %%
my_df = pd.DataFrame(data, columns=['first', 'last', 'sex', 'DOB', 'DOD', 'parents', 'INDI_ID'])

# %%
my_df[1:20]
# Out:
#                 first      last sex   DOB   DOD  \
# 1                Mary    Hutton   F  1869  1925
# 2                Mary     Hewes   F  1842  1874
# 3        John William    Biddle   M  1835  1916
# 4      Addison Hutton    Biddle   M  1903  1912
# 5                Ruth    Biddle   F  1906  1969
# 6      Rebecca Hutton    Biddle   F  1901  1991
# 7   Elizabeth Rebecca    Biddle   F  1897  1975
# 8             Dorothy    Biddle   F  1900  1985
# 9          Mary Hewes    Biddle   F  1898  1963
# 10          Ruth Ella  Chambers   F  1870  1948
# 11            William    Biddle   M  1806  1887
# 12   Elizabeth Cesson    Biddle   F    -1  1881
# 13            William    Biddle   M  1863  1948
# 14            Rebecca    Savery   F  1836  1902
# 15            Addison    Hutton   M  1834  1916
# 16            Sarah S   Garrett   F  1819  1853
# 17           Edward C     Hewes   M  1821  1880
# 18      Margaret Cope     James   F  1935  1979
# 19    Caroline Biddle     James   F  1932  2012
#
#                                  parents INDI_ID
# 1   [0 @P16@ INDI\r\n, 0 @P15@ INDI\r\n]    @P2@
# 2   [0 @P18@ INDI\r\n, 0 @P17@ INDI\r\n]    @P3@
# 3   [0 @P12@ INDI\r\n, 0 @P13@ INDI\r\n]    @P4@
# 4     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P5@
# 5     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P6@
# 6     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P7@
# 7     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P8@
# 8     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P9@
# 9     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]   @P10@
# 10                                    []   @P11@
# 11                                    []   @P12@
# 12                                    []   @P13@
# 13    [0 @P4@ INDI\r\n, 0 @P3@ INDI\r\n]   @P14@
# 14                                    []   @P15@
# 15  [0 @P39@ INDI\r\n, 0 @P40@ INDI\r\n]   @P16@
# 16                                    []   @P17@
# 17                                    []   @P18@
# 18   [0 @P23@ INDI\r\n, 0 @P9@ INDI\r\n]   @P19@
# 19   [0 @P23@ INDI\r\n, 0 @P9@ INDI\r\n]   @P20@

# %% [markdown]
# This is getting close, but I want to split the parents column into Parent1 and Parent2 at the comma. However, I can't do that until I fill the empty values ([]). These are not na values (see below for the .isna() test), do not respond to calling '[]', and do not seem to be actually empty either.

# %% [markdown]
# I've tried lots of ways of taking out the [] in the parents column-- the easiest by far was search and replace in Excel as Regex has been difficult with [] characters. But that takes the gedcom parser back a level and loses the individual @P23@ tag, which marks each individual with a unique identifier. (see below, my_df2) Additionally, I'll need to replace the -1 for an unknown or nonexistent date with NaN.

# %%
my_df.isna().head()
# Out:
#    first   last    sex    DOB    DOD  parents  INDI_ID
# 0  False  False  False  False  False    False    False
# 1  False  False  False  False  False    False    False
# 2  False  False  False  False  False    False    False
# 3  False  False  False  False  False    False    False
# 4  False  False  False  False  False    False    False

# %%
my_df = my_df.replace('\[\]', 'NaN')

# %%
my_df[1:20]
# Out:
#                 first      last sex   DOB   DOD  \
# 1                Mary    Hutton   F  1869  1925
# 2                Mary     Hewes   F  1842  1874
# 3        John William    Biddle   M  1835  1916
# 4      Addison Hutton    Biddle   M  1903  1912
# 5                Ruth    Biddle   F  1906  1969
# 6      Rebecca Hutton    Biddle   F  1901  1991
# 7   Elizabeth Rebecca    Biddle   F  1897  1975
# 8             Dorothy    Biddle   F  1900  1985
# 9          Mary Hewes    Biddle   F  1898  1963
# 10          Ruth Ella  Chambers   F  1870  1948
# 11            William    Biddle   M  1806  1887
# 12   Elizabeth Cesson    Biddle   F    -1  1881
# 13            William    Biddle   M  1863  1948
# 14            Rebecca    Savery   F  1836  1902
# 15            Addison    Hutton   M  1834  1916
# 16            Sarah S   Garrett   F  1819  1853
# 17           Edward C     Hewes   M  1821  1880
# 18      Margaret Cope     James   F  1935  1979
# 19    Caroline Biddle     James   F  1932  2012
#
#                                  parents INDI_ID
# 1   [0 @P16@ INDI\r\n, 0 @P15@ INDI\r\n]    @P2@
# 2   [0 @P18@ INDI\r\n, 0 @P17@ INDI\r\n]    @P3@
# 3   [0 @P12@ INDI\r\n, 0 @P13@ INDI\r\n]    @P4@
# 4     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P5@
# 5     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P6@
# 6     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P7@
# 7     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P8@
# 8     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P9@
# 9     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]   @P10@
# 10                                    []   @P11@
# 11                                    []   @P12@
# 12                                    []   @P13@
# 13    [0 @P4@ INDI\r\n, 0 @P3@ INDI\r\n]   @P14@
# 14                                    []   @P15@
# 15  [0 @P39@ INDI\r\n, 0 @P40@ INDI\r\n]   @P16@
# 16                                    []   @P17@
# 17                                    []   @P18@
# 18   [0 @P23@ INDI\r\n, 0 @P9@ INDI\r\n]   @P19@
# 19   [0 @P23@ INDI\r\n, 0 @P9@ INDI\r\n]   @P20@

# %%
#my_df[['parent_1', 'parent_2']] = my_df.parents.str.split(",", expand=True)

# %%
#for i in my_df[parents]:
 #   if i

# %%
my_df.to_csv('JGB_MHB.csv')

# %%
my_df2 = pd.read_csv('JGB_MHB.csv') #this csv has had empty values replaced using Excel

# %%
my_df2.head()
# Out:
#    Unnamed: 0           first    last sex   DOB   DOD  \
# 0           0   James Garrett  Biddle   M  1868  1947
# 1           1            Mary  Hutton   F  1869  1925
# 2           2            Mary   Hewes   F  1842  1874
# 3           3    John William  Biddle   M  1835  1916
# 4           4  Addison Hutton  Biddle   M  1903  1912
#
#                                              parents INDI_ID
# 0  [<gedcom.element.individual.IndividualElement ...    @P1@
# 1  [<gedcom.element.individual.IndividualElement ...    @P2@
# 2  [<gedcom.element.individual.IndividualElement ...    @P3@
# 3  [<gedcom.element.individual.IndividualElement ...    @P4@
# 4  [<gedcom.element.individual.IndividualElement ...    @P5@
