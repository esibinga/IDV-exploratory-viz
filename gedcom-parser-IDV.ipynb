# %% [markdown]
# My goal here is to create a csv from genealogical data I have in a GEDCOM file. Ideally I'd like the data to be a JSON file so that I can use it for hierarchical data viz, but I've had trouble converting directly from GEDCOM to JSON. I'm going to try the intermediate step of CSV here using a GEDCOM parse package and pandas.

# %%
pip install python-gedcom
# Out:
# Collecting python-gedcom
#   Downloading https://files.pythonhosted.org/packages/1d/c0/20b56a9cf44fac3c25799e5a84b6a719ec7d7bc47501c9fe2b484bdabba5/python_gedcom-1.0.0-py2.py3-none-any.whl
# Installing collected packages: python-gedcom
# Successfully installed python-gedcom-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#install gedcom packages
from gedcom.element.individual import IndividualElement
from gedcom.parser import Parser

# %%
import os
os.getcwd()
# Out:
# '/Users/evasibinga'

# %%
#install dataframe packages needed
import pandas as pd

# %%
#create empty dataframe ## didn't end up using this but it was a helpful starting place
col_names = ['INDI', 'first', 'last', 'full_name', 'family', 'sex', 'DOB', 'DOD', 'birthplace', 'deathplace', 'generation', 'level', 'parent_id' ]
my_df = pd.DataFrame(columns=col_names)

# %%
my_df
# Out:
# Empty DataFrame
# Columns: [INDI, first, last, full_name, family, sex, DOB, DOD, birthplace, deathplace, generation, parent_id]
# Index: []

# %%
#file path to my gedcom file
file_path = 'IDV-exploratory-viz/data/JGB_MHB.ged'

# %%
#initialize gedcom parser
gedcom_parser = Parser()

# %%
gedcom_parser.parse_file(file_path)

# %%
root_child_elements = gedcom_parser.get_root_child_elements()

# %%
root_child_elements
# Out:
# [<gedcom.element.element.Element at 0x10bd5fc18>,
#  <gedcom.element.individual.IndividualElement at 0x10bd746d8>,
#  <gedcom.element.individual.IndividualElement at 0x10bd8a4e0>,
#  <gedcom.element.individual.IndividualElement at 0x10bd9f1d0>,
#  <gedcom.element.individual.IndividualElement at 0x10bda7f60>,
#  <gedcom.element.individual.IndividualElement at 0x10bdb84e0>,
#  <gedcom.element.individual.IndividualElement at 0x10bdc0e48>,
#  <gedcom.element.individual.IndividualElement at 0x10bddef98>,
#  <gedcom.element.individual.IndividualElement at 0x10bdf8240>,
#  <gedcom.element.individual.IndividualElement at 0x10be0e940>,
#  <gedcom.element.individual.IndividualElement at 0x10be24400>,
#  <gedcom.element.individual.IndividualElement at 0x10be33390>,
#  <gedcom.element.individual.IndividualElement at 0x10be36e48>,
#  <gedcom.element.individual.IndividualElement at 0x10be39d68>,
#  <gedcom.element.individual.IndividualElement at 0x10be3c898>,
#  <gedcom.element.individual.IndividualElement at 0x10be414a8>,
#  <gedcom.element.individual.IndividualElement at 0x10be53278>,
#  <gedcom.element.individual.IndividualElement at 0x10be62898>,
#  <gedcom.element.individual.IndividualElement at 0x10be64278>,
#  <gedcom.element.individual.IndividualElement at 0x10be64c18>,
#  <gedcom.element.individual.IndividualElement at 0x10be6f400>,
#  <gedcom.element.individual.IndividualElement at 0x10be7c710>,
#  <gedcom.element.individual.IndividualElement at 0x10be8aba8>,
#  <gedcom.element.individual.IndividualElement at 0x10be8f710>,
#  <gedcom.element.individual.IndividualElement at 0x10bea6d68>,
#  <gedcom.element.individual.IndividualElement at 0x10beb6da0>,
#  <gedcom.element.individual.IndividualElement at 0x10bec0978>,
#  <gedcom.element.individual.IndividualElement at 0x10becdeb8>,
#  <gedcom.element.individual.IndividualElement at 0x10bee63c8>,
#  <gedcom.element.individual.IndividualElement at 0x10bef42b0>,
#  <gedcom.element.individual.IndividualElement at 0x10bf05780>,
#  <gedcom.element.individual.IndividualElement at 0x10bf14b38>,
#  <gedcom.element.individual.IndividualElement at 0x10bf1c860>,
#  <gedcom.element.individual.IndividualElement at 0x10bf3b240>,
#  <gedcom.element.individual.IndividualElement at 0x10bf4e0f0>,
#  <gedcom.element.individual.IndividualElement at 0x10bf5c7f0>,
#  <gedcom.element.individual.IndividualElement at 0x10bf6e668>,
#  <gedcom.element.individual.IndividualElement at 0x10bf81ba8>,
#  <gedcom.element.individual.IndividualElement at 0x10bf8d550>,
#  <gedcom.element.individual.IndividualElement at 0x10bfa8240>,
#  <gedcom.element.individual.IndividualElement at 0x10bfadd30>,
#  <gedcom.element.individual.IndividualElement at 0x10bfb44e0>,
#  <gedcom.element.individual.IndividualElement at 0x10bfb9208>,
#  <gedcom.element.individual.IndividualElement at 0x10bfbbc18>,
#  <gedcom.element.individual.IndividualElement at 0x10bfbd898>,
#  <gedcom.element.individual.IndividualElement at 0x10bfbddd8>,
#  <gedcom.element.individual.IndividualElement at 0x10bfc0470>,
#  <gedcom.element.individual.IndividualElement at 0x10bfc3908>,
#  <gedcom.element.individual.IndividualElement at 0x10bfc5048>,
#  <gedcom.element.individual.IndividualElement at 0x10bfc9668>,
#  <gedcom.element.individual.IndividualElement at 0x10bfcc048>,
#  <gedcom.element.individual.IndividualElement at 0x10bfd2a90>,
#  <gedcom.element.individual.IndividualElement at 0x10bfdb908>,
#  <gedcom.element.individual.IndividualElement at 0x10bfdd3c8>,
#  <gedcom.element.individual.IndividualElement at 0x10bfdd9e8>,
#  <gedcom.element.individual.IndividualElement at 0x10bfe2908>,
#  <gedcom.element.individual.IndividualElement at 0x10bfe5da0>,
#  <gedcom.element.individual.IndividualElement at 0x10bfeacc0>,
#  <gedcom.element.individual.IndividualElement at 0x10bff7278>,
#  <gedcom.element.individual.IndividualElement at 0x10bff8470>,
#  <gedcom.element.individual.IndividualElement at 0x10bffb2e8>,
#  <gedcom.element.individual.IndividualElement at 0x10bffe160>,
#  <gedcom.element.individual.IndividualElement at 0x10c0018d0>,
#  <gedcom.element.individual.IndividualElement at 0x10c003940>,
#  <gedcom.element.individual.IndividualElement at 0x10c006860>,
#  <gedcom.element.individual.IndividualElement at 0x10c008c18>,
#  <gedcom.element.individual.IndividualElement at 0x10c00d0f0>,
#  <gedcom.element.individual.IndividualElement at 0x10c0104a8>,
#  <gedcom.element.individual.IndividualElement at 0x10c015c18>,
#  <gedcom.element.individual.IndividualElement at 0x10c01a208>,
#  <gedcom.element.individual.IndividualElement at 0x10c01f860>,
#  <gedcom.element.individual.IndividualElement at 0x10c025f98>,
#  <gedcom.element.individual.IndividualElement at 0x10c028b00>,
#  <gedcom.element.individual.IndividualElement at 0x10c02acc0>,
#  <gedcom.element.individual.IndividualElement at 0x10c02f1d0>,
#  <gedcom.element.individual.IndividualElement at 0x10c0353c8>,
#  <gedcom.element.individual.IndividualElement at 0x10c0396a0>,
#  <gedcom.element.individual.IndividualElement at 0x10c03a940>,
#  <gedcom.element.individual.IndividualElement at 0x10c03c358>,
#  <gedcom.element.individual.IndividualElement at 0x10c03fdd8>,
#  <gedcom.element.individual.IndividualElement at 0x10c0440f0>,
#  <gedcom.element.individual.IndividualElement at 0x10c046128>,
#  <gedcom.element.individual.IndividualElement at 0x10c046710>,
#  <gedcom.element.individual.IndividualElement at 0x10c0490b8>,
#  <gedcom.element.individual.IndividualElement at 0x10c0536d8>,
#  <gedcom.element.individual.IndividualElement at 0x10c058278>,
#  <gedcom.element.individual.IndividualElement at 0x10c05b358>,
#  <gedcom.element.individual.IndividualElement at 0x10c05de80>,
#  <gedcom.element.individual.IndividualElement at 0x10c060e48>,
#  <gedcom.element.individual.IndividualElement at 0x10c065780>,
#  <gedcom.element.individual.IndividualElement at 0x10c068860>,
#  <gedcom.element.individual.IndividualElement at 0x10c06b630>,
#  <gedcom.element.individual.IndividualElement at 0x10c06df28>,
#  <gedcom.element.individual.IndividualElement at 0x10c072a20>,
#  <gedcom.element.individual.IndividualElement at 0x10c078710>,
#  <gedcom.element.individual.IndividualElement at 0x10c07e400>,
#  <gedcom.element.individual.IndividualElement at 0x10c07e860>,
#  <gedcom.element.individual.IndividualElement at 0x10c07ecc0>,
#  <gedcom.element.individual.IndividualElement at 0x10c080160>,
#  <gedcom.element.individual.IndividualElement at 0x10c0809b0>,
#  <gedcom.element.individual.IndividualElement at 0x10c0843c8>,
#  <gedcom.element.individual.IndividualElement at 0x10c084ef0>,
#  <gedcom.element.individual.IndividualElement at 0x10c0864e0>,
#  <gedcom.element.individual.IndividualElement at 0x10c086be0>,
#  <gedcom.element.individual.IndividualElement at 0x10c0895f8>,
#  <gedcom.element.individual.IndividualElement at 0x10c08e860>,
#  <gedcom.element.individual.IndividualElement at 0x10c095c50>,
#  <gedcom.element.individual.IndividualElement at 0x10c097588>,
#  <gedcom.element.individual.IndividualElement at 0x10c09b320>,
#  <gedcom.element.individual.IndividualElement at 0x10c0a35c0>,
#  <gedcom.element.individual.IndividualElement at 0x10c0a9828>,
#  <gedcom.element.individual.IndividualElement at 0x10c0aba58>,
#  <gedcom.element.individual.IndividualElement at 0x10c0abf98>,
#  <gedcom.element.individual.IndividualElement at 0x10c0b06d8>,
#  <gedcom.element.individual.IndividualElement at 0x10c0b2a90>,
#  <gedcom.element.individual.IndividualElement at 0x10c0b5978>,
#  <gedcom.element.individual.IndividualElement at 0x10c0b7208>,
#  <gedcom.element.individual.IndividualElement at 0x10c0ba320>,
#  <gedcom.element.individual.IndividualElement at 0x10c0baeb8>,
#  <gedcom.element.individual.IndividualElement at 0x10c0bcc18>,
#  <gedcom.element.individual.IndividualElement at 0x10c0c3dd8>,
#  <gedcom.element.individual.IndividualElement at 0x10c0c9828>,
#  <gedcom.element.individual.IndividualElement at 0x10c0cfa90>,
#  <gedcom.element.individual.IndividualElement at 0x10c0d4b00>,
#  <gedcom.element.individual.IndividualElement at 0x10c0dc0f0>,
#  <gedcom.element.individual.IndividualElement at 0x10c0e16a0>,
#  <gedcom.element.individual.IndividualElement at 0x10c0e50b8>,
#  <gedcom.element.individual.IndividualElement at 0x10c0eb2e8>,
#  <gedcom.element.individual.IndividualElement at 0x10c0edcf8>,
#  <gedcom.element.individual.IndividualElement at 0x10c0f4748>,
#  <gedcom.element.individual.IndividualElement at 0x10c0f4ef0>,
#  <gedcom.element.individual.IndividualElement at 0x10c0f6c88>,
#  <gedcom.element.individual.IndividualElement at 0x10c0fb828>,
#  <gedcom.element.individual.IndividualElement at 0x10c0fbd30>,
#  <gedcom.element.individual.IndividualElement at 0x10c100cf8>,
#  <gedcom.element.individual.IndividualElement at 0x10c1014e0>,
#  <gedcom.element.individual.IndividualElement at 0x10c101978>,
#  <gedcom.element.individual.IndividualElement at 0x10c101e10>,
#  <gedcom.element.individual.IndividualElement at 0x10c1052e8>,
#  <gedcom.element.individual.IndividualElement at 0x10c1057f0>,
#  <gedcom.element.individual.IndividualElement at 0x10c105cf8>,
#  <gedcom.element.individual.IndividualElement at 0x10c1061d0>,
#  <gedcom.element.individual.IndividualElement at 0x10c1066d8>,
#  <gedcom.element.individual.IndividualElement at 0x10c106c18>,
#  <gedcom.element.individual.IndividualElement at 0x10c1090f0>,
#  <gedcom.element.individual.IndividualElement at 0x10c109588>,
#  <gedcom.element.individual.IndividualElement at 0x10c109d68>,
#  <gedcom.element.individual.IndividualElement at 0x10c10b208>,
#  <gedcom.element.individual.IndividualElement at 0x10c10b668>,
#  <gedcom.element.individual.IndividualElement at 0x10c10bac8>,
#  <gedcom.element.individual.IndividualElement at 0x10c10e048>,
#  <gedcom.element.individual.IndividualElement at 0x10c10e358>,
#  <gedcom.element.individual.IndividualElement at 0x10c10e668>,
#  <gedcom.element.individual.IndividualElement at 0x10c10eac8>,
#  <gedcom.element.individual.IndividualElement at 0x10c110438>,
#  <gedcom.element.individual.IndividualElement at 0x10c110898>,
#  <gedcom.element.individual.IndividualElement at 0x10c110fd0>,
#  <gedcom.element.individual.IndividualElement at 0x10c111550>,
#  <gedcom.element.individual.IndividualElement at 0x10c111a90>,
#  <gedcom.element.individual.IndividualElement at 0x10c111fd0>,
#  <gedcom.element.individual.IndividualElement at 0x10c115320>,
#  <gedcom.element.individual.IndividualElement at 0x10c115780>,
#  <gedcom.element.individual.IndividualElement at 0x10c115be0>,
#  <gedcom.element.individual.IndividualElement at 0x10c1161d0>,
#  <gedcom.element.individual.IndividualElement at 0x10c116630>,
#  <gedcom.element.individual.IndividualElement at 0x10c11a5f8>,
#  <gedcom.element.individual.IndividualElement at 0x10c11aa58>,
#  <gedcom.element.individual.IndividualElement at 0x10c11aeb8>,
#  <gedcom.element.individual.IndividualElement at 0x10c11b358>,
#  <gedcom.element.individual.IndividualElement at 0x10c11bcf8>,
#  <gedcom.element.individual.IndividualElement at 0x10c11e198>,
#  <gedcom.element.individual.IndividualElement at 0x10c11ec88>,
#  <gedcom.element.individual.IndividualElement at 0x10c1207b8>,
#  <gedcom.element.individual.IndividualElement at 0x10c1247b8>,
#  <gedcom.element.individual.IndividualElement at 0x10c124b00>,
#  <gedcom.element.individual.IndividualElement at 0x10c126048>,
#  <gedcom.element.individual.IndividualElement at 0x10c126b38>,
#  <gedcom.element.individual.IndividualElement at 0x10c12a668>,
#  <gedcom.element.individual.IndividualElement at 0x10c12c128>,
#  <gedcom.element.individual.IndividualElement at 0x10c12cc18>,
#  <gedcom.element.individual.IndividualElement at 0x10c12f748>,
#  <gedcom.element.individual.IndividualElement at 0x10c131278>,
#  <gedcom.element.individual.IndividualElement at 0x10c1361d0>,
#  <gedcom.element.individual.IndividualElement at 0x10c136630>,
#  <gedcom.element.individual.IndividualElement at 0x10c136a90>,
#  <gedcom.element.individual.IndividualElement at 0x10c136ef0>,
#  <gedcom.element.individual.IndividualElement at 0x10c138390>,
#  <gedcom.element.individual.IndividualElement at 0x10c1387f0>,
#  <gedcom.element.individual.IndividualElement at 0x10c138c50>,
#  <gedcom.element.individual.IndividualElement at 0x10c13b0f0>,
#  <gedcom.element.individual.IndividualElement at 0x10c13b550>,
#  <gedcom.element.individual.IndividualElement at 0x10c13b9b0>,
#  <gedcom.element.individual.IndividualElement at 0x10c13cac8>,
#  <gedcom.element.individual.IndividualElement at 0x10c13cf28>,
#  <gedcom.element.individual.IndividualElement at 0x10c1403c8>,
#  <gedcom.element.individual.IndividualElement at 0x10c140828>,
#  <gedcom.element.individual.IndividualElement at 0x10c140c88>,
#  <gedcom.element.individual.IndividualElement at 0x10c141128>,
#  <gedcom.element.individual.IndividualElement at 0x10c141ac8>,
#  <gedcom.element.individual.IndividualElement at 0x10c141f60>,
#  <gedcom.element.individual.IndividualElement at 0x10c145400>,
#  <gedcom.element.individual.IndividualElement at 0x10c145860>,
#  <gedcom.element.individual.IndividualElement at 0x10c145cc0>,
#  <gedcom.element.individual.IndividualElement at 0x10c147940>,
#  <gedcom.element.individual.IndividualElement at 0x10c147da0>,
#  <gedcom.element.individual.IndividualElement at 0x10c14a240>,
#  <gedcom.element.individual.IndividualElement at 0x10c14aeb8>,
#  <gedcom.element.individual.IndividualElement at 0x10c14c208>,
#  <gedcom.element.individual.IndividualElement at 0x10c14c748>,
#  <gedcom.element.individual.IndividualElement at 0x10c14cba8>,
#  <gedcom.element.individual.IndividualElement at 0x10c14f048>,
#  <gedcom.element.individual.IndividualElement at 0x10c14f358>,
#  <gedcom.element.individual.IndividualElement at 0x10c14f668>,
#  <gedcom.element.individual.IndividualElement at 0x10c14fac8>,
#  <gedcom.element.individual.IndividualElement at 0x10c14ff28>,
#  <gedcom.element.individual.IndividualElement at 0x10c1513c8>,
#  <gedcom.element.individual.IndividualElement at 0x10c151828>,
#  <gedcom.element.individual.IndividualElement at 0x10c151c88>,
#  <gedcom.element.individual.IndividualElement at 0x10c152160>,
#  <gedcom.element.individual.IndividualElement at 0x10c152668>,
#  <gedcom.element.individual.IndividualElement at 0x10c152b70>,
#  <gedcom.element.individual.IndividualElement at 0x10c156198>,
#  <gedcom.element.individual.IndividualElement at 0x10c1565f8>,
#  <gedcom.element.individual.IndividualElement at 0x10c156a58>,
#  <gedcom.element.individual.IndividualElement at 0x10c156f60>,
#  <gedcom.element.individual.IndividualElement at 0x10c1574a8>,
#  <gedcom.element.individual.IndividualElement at 0x10c1579b0>,
#  <gedcom.element.individual.IndividualElement at 0x10c157eb8>,
#  <gedcom.element.individual.IndividualElement at 0x10c15a400>,
#  <gedcom.element.individual.IndividualElement at 0x10c15a9e8>,
#  <gedcom.element.individual.IndividualElement at 0x10c15aef0>,
#  <gedcom.element.individual.IndividualElement at 0x10c15c470>,
#  <gedcom.element.individual.IndividualElement at 0x10c15c9b0>,
#  <gedcom.element.individual.IndividualElement at 0x10c15ceb8>,
#  <gedcom.element.individual.IndividualElement at 0x10c15f9e8>,
#  <gedcom.element.individual.IndividualElement at 0x10c1616a0>,
#  <gedcom.element.individual.IndividualElement at 0x10c161b00>,
#  <gedcom.element.individual.IndividualElement at 0x10c161e10>,
#  <gedcom.element.individual.IndividualElement at 0x10c1642b0>,
#  <gedcom.element.individual.IndividualElement at 0x10c1645c0>,
#  <gedcom.element.individual.IndividualElement at 0x10c164ac8>,
#  <gedcom.element.individual.IndividualElement at 0x10c164fd0>,
#  <gedcom.element.individual.IndividualElement at 0x10c166518>,
#  <gedcom.element.individual.IndividualElement at 0x10c169b38>,
#  <gedcom.element.individual.IndividualElement at 0x10c16d198>,
#  <gedcom.element.individual.IndividualElement at 0x10c16d6a0>,
#  <gedcom.element.individual.IndividualElement at 0x10c16dc88>,
#  <gedcom.element.individual.IndividualElement at 0x10c16f7f0>,
#  <gedcom.element.individual.IndividualElement at 0x10c1729b0>,
#  <gedcom.element.individual.IndividualElement at 0x10c1753c8>,
#  <gedcom.element.individual.IndividualElement at 0x10c175860>,
#  <gedcom.element.individual.IndividualElement at 0x10c175cc0>,
#  <gedcom.element.individual.IndividualElement at 0x10c177160>,
#  <gedcom.element.individual.IndividualElement at 0x10c177668>,
#  <gedcom.element.individual.IndividualElement at 0x10c177c50>,
#  <gedcom.element.individual.IndividualElement at 0x10c17a9e8>,
#  <gedcom.element.individual.IndividualElement at 0x10c17ae48>,
#  <gedcom.element.individual.IndividualElement at 0x10c17c2e8>,
#  <gedcom.element.individual.IndividualElement at 0x10c17cc18>,
#  <gedcom.element.individual.IndividualElement at 0x10c17f0b8>,
#  <gedcom.element.individual.IndividualElement at 0x10c17f5c0>,
#  <gedcom.element.individual.IndividualElement at 0x10c17fa20>,
#  <gedcom.element.individual.IndividualElement at 0x10c17fe80>,
#  <gedcom.element.individual.IndividualElement at 0x10c180320>,
#  <gedcom.element.individual.IndividualElement at 0x10c180828>,
#  <gedcom.element.individual.IndividualElement at 0x10c180d30>,
#  <gedcom.element.individual.IndividualElement at 0x10c184208>,
#  <gedcom.element.individual.IndividualElement at 0x10c1846a0>,
#  <gedcom.element.individual.IndividualElement at 0x10c184ba8>,
#  <gedcom.element.individual.IndividualElement at 0x10c185080>,
#  <gedcom.element.individual.IndividualElement at 0x10c185518>,
#  <gedcom.element.individual.IndividualElement at 0x10c185978>,
#  <gedcom.element.individual.IndividualElement at 0x10c185dd8>,
#  <gedcom.element.individual.IndividualElement at 0x10c187278>,
#  <gedcom.element.individual.IndividualElement at 0x10c1876d8>,
#  <gedcom.element.individual.IndividualElement at 0x10c187b38>,
#  <gedcom.element.individual.IndividualElement at 0x10c187f98>,
#  <gedcom.element.family.FamilyElement at 0x10c18a400>,
#  <gedcom.element.family.FamilyElement at 0x10c18be80>,
#  <gedcom.element.family.FamilyElement at 0x10c18f5f8>,
#  <gedcom.element.family.FamilyElement at 0x10c190160>,
#  <gedcom.element.family.FamilyElement at 0x10c190dd8>,
#  <gedcom.element.family.FamilyElement at 0x10c194c88>,
#  <gedcom.element.family.FamilyElement at 0x10c196940>,
#  <gedcom.element.family.FamilyElement at 0x10c197390>,
#  <gedcom.element.family.FamilyElement at 0x10c19a828>,
#  <gedcom.element.family.FamilyElement at 0x10c19c780>,
#  <gedcom.element.family.FamilyElement at 0x10c19d240>,
#  <gedcom.element.family.FamilyElement at 0x10c19deb8>,
#  <gedcom.element.family.FamilyElement at 0x10c1a1f60>,
#  <gedcom.element.family.FamilyElement at 0x10c1a3780>,
#  <gedcom.element.family.FamilyElement at 0x10c1a62e8>,
#  <gedcom.element.family.FamilyElement at 0x10c1a68d0>,
#  <gedcom.element.family.FamilyElement at 0x10c1a6b70>,
#  <gedcom.element.family.FamilyElement at 0x10c1a8828>,
#  <gedcom.element.family.FamilyElement at 0x10c1a8cc0>,
#  <gedcom.element.family.FamilyElement at 0x10c1a9b70>,
#  <gedcom.element.family.FamilyElement at 0x10c1a9e10>,
#  <gedcom.element.family.FamilyElement at 0x10c1ac588>,
#  <gedcom.element.family.FamilyElement at 0x10c1ae198>,
#  <gedcom.element.family.FamilyElement at 0x10c1ae978>,
#  <gedcom.element.family.FamilyElement at 0x10c1b00f0>,
#  <gedcom.element.family.FamilyElement at 0x10c1b0828>,
#  <gedcom.element.family.FamilyElement at 0x10c1b2c18>,
#  <gedcom.element.family.FamilyElement at 0x10c1b4ac8>,
#  <gedcom.element.family.FamilyElement at 0x10c1b6780>,
#  <gedcom.element.family.FamilyElement at 0x10c1b88d0>,
#  <gedcom.element.family.FamilyElement at 0x10c1bb390>,
#  <gedcom.element.family.FamilyElement at 0x10c1be048>,
#  <gedcom.element.family.FamilyElement at 0x10c1be828>,
#  <gedcom.element.family.FamilyElement at 0x10c1c1048>,
#  <gedcom.element.family.FamilyElement at 0x10c1c1eb8>,
#  <gedcom.element.family.FamilyElement at 0x10c1c2198>,
#  <gedcom.element.family.FamilyElement at 0x10c1c2d68>,
#  <gedcom.element.family.FamilyElement at 0x10c1c42e8>,
#  <gedcom.element.family.FamilyElement at 0x10c1c4710>,
#  <gedcom.element.family.FamilyElement at 0x10c1c73c8>,
#  <gedcom.element.family.FamilyElement at 0x10c1c7dd8>,
#  <gedcom.element.family.FamilyElement at 0x10c1c9748>,
#  <gedcom.element.family.FamilyElement at 0x10c1c9f28>,
#  <gedcom.element.family.FamilyElement at 0x10c1cc940>,
#  <gedcom.element.family.FamilyElement at 0x10c1ce748>,
#  <gedcom.element.family.FamilyElement at 0x10c1d0400>,
#  <gedcom.element.family.FamilyElement at 0x10c1d0828>,
#  <gedcom.element.family.FamilyElement at 0x10c1d4668>,
#  <gedcom.element.family.FamilyElement at 0x10c1d5470>,
#  <gedcom.element.family.FamilyElement at 0x10c1d8080>,
#  <gedcom.element.family.FamilyElement at 0x10c1d8ef0>,
#  <gedcom.element.family.FamilyElement at 0x10c1daa58>,
#  <gedcom.element.family.FamilyElement at 0x10c1dc470>,
#  <gedcom.element.family.FamilyElement at 0x10c1dc860>,
#  <gedcom.element.family.FamilyElement at 0x10c1de128>,
#  <gedcom.element.family.FamilyElement at 0x10c1decf8>,
#  <gedcom.element.family.FamilyElement at 0x10c1e0470>,
#  <gedcom.element.family.FamilyElement at 0x10c1e0e48>,
#  <gedcom.element.family.FamilyElement at 0x10c1e3278>,
#  <gedcom.element.family.FamilyElement at 0x10c1e3da0>,
#  <gedcom.element.family.FamilyElement at 0x10c1e4320>,
#  <gedcom.element.family.FamilyElement at 0x10c1e4cf8>,
#  <gedcom.element.family.FamilyElement at 0x10c1e6ba8>,
#  <gedcom.element.family.FamilyElement at 0x10c1e9518>,
#  <gedcom.element.family.FamilyElement at 0x10c1e9e80>,
#  <gedcom.element.family.FamilyElement at 0x10c1ea4e0>,
#  <gedcom.element.family.FamilyElement at 0x10c1ee0f0>,
#  <gedcom.element.family.FamilyElement at 0x10c1ef240>,
#  <gedcom.element.family.FamilyElement at 0x10c1ef828>,
#  <gedcom.element.family.FamilyElement at 0x10c1f1198>,
#  <gedcom.element.family.FamilyElement at 0x10c1f1828>,
#  <gedcom.element.family.FamilyElement at 0x10c1f54e0>,
#  <gedcom.element.family.FamilyElement at 0x10c1f5cc0>,
#  <gedcom.element.family.FamilyElement at 0x10c1f6e10>,
#  <gedcom.element.family.FamilyElement at 0x10c1f9ac8>,
#  <gedcom.element.family.FamilyElement at 0x10c1fb2e8>,
#  <gedcom.element.family.FamilyElement at 0x10c1fbd68>,
#  <gedcom.element.family.FamilyElement at 0x10c1fc630>,
#  <gedcom.element.family.FamilyElement at 0x10c1ff240>,
#  <gedcom.element.family.FamilyElement at 0x10c1ff978>,
#  <gedcom.element.family.FamilyElement at 0x10c2028d0>,
#  <gedcom.element.family.FamilyElement at 0x10c2032e8>,
#  <gedcom.element.family.FamilyElement at 0x10c203828>,
#  <gedcom.element.family.FamilyElement at 0x10c206588>,
#  <gedcom.element.family.FamilyElement at 0x10c206eb8>,
#  <gedcom.element.family.FamilyElement at 0x10c208438>,
#  <gedcom.element.family.FamilyElement at 0x10c208978>,
#  <gedcom.element.family.FamilyElement at 0x10c20aa20>,
#  <gedcom.element.family.FamilyElement at 0x10c20d198>,
#  <gedcom.element.family.FamilyElement at 0x10c20d828>,
#  <gedcom.element.family.FamilyElement at 0x10c20dd68>,
#  <gedcom.element.family.FamilyElement at 0x10c20e2e8>,
#  <gedcom.element.family.FamilyElement at 0x10c20e828>,
#  <gedcom.element.element.Element at 0x10c20eb70>,
#  <gedcom.element.element.Element at 0x10c20ecc0>,
#  <gedcom.element.element.Element at 0x10c20ee10>,
#  <gedcom.element.element.Element at 0x10c2110f0>,
#  <gedcom.element.element.Element at 0x10c2114e0>,
#  <gedcom.element.element.Element at 0x10c2118d0>,
#  <gedcom.element.element.Element at 0x10c211cc0>,
#  <gedcom.element.element.Element at 0x10c2150f0>,
#  <gedcom.element.element.Element at 0x10c2154e0>,
#  <gedcom.element.element.Element at 0x10c2158d0>,
#  <gedcom.element.element.Element at 0x10c215cc0>,
#  <gedcom.element.element.Element at 0x10c2180f0>,
#  <gedcom.element.element.Element at 0x10c2184e0>,
#  <gedcom.element.element.Element at 0x10c2188d0>,
#  <gedcom.element.element.Element at 0x10c218cc0>,
#  <gedcom.element.element.Element at 0x10c21a0f0>,
#  <gedcom.element.element.Element at 0x10c21a4e0>,
#  <gedcom.element.element.Element at 0x10c21a8d0>,
#  <gedcom.element.element.Element at 0x10c21acc0>,
#  <gedcom.element.element.Element at 0x10c21d0f0>,
#  <gedcom.element.element.Element at 0x10c21d4e0>,
#  <gedcom.element.element.Element at 0x10c21d8d0>,
#  <gedcom.element.element.Element at 0x10c21db70>,
#  <gedcom.element.element.Element at 0x10c21df60>,
#  <gedcom.element.element.Element at 0x10c221390>,
#  <gedcom.element.element.Element at 0x10c221780>,
#  <gedcom.element.element.Element at 0x10c221b70>,
#  <gedcom.element.element.Element at 0x10c221f60>,
#  <gedcom.element.element.Element at 0x10c222390>,
#  <gedcom.element.element.Element at 0x10c222780>,
#  <gedcom.element.element.Element at 0x10c222b70>,
#  <gedcom.element.element.Element at 0x10c222f60>,
#  <gedcom.element.element.Element at 0x10c225390>,
#  <gedcom.element.element.Element at 0x10c225780>,
#  <gedcom.element.element.Element at 0x10c225b70>,
#  <gedcom.element.element.Element at 0x10c225f60>,
#  <gedcom.element.element.Element at 0x10c228390>,
#  <gedcom.element.element.Element at 0x10c228780>,
#  <gedcom.element.element.Element at 0x10c228b70>,
#  <gedcom.element.element.Element at 0x10c228f60>,
#  <gedcom.element.element.Element at 0x10c22a390>,
#  <gedcom.element.element.Element at 0x10c22a780>,
#  <gedcom.element.element.Element at 0x10c22ab70>,
#  <gedcom.element.element.Element at 0x10c22af60>,
#  <gedcom.element.element.Element at 0x10c22d390>,
#  <gedcom.element.element.Element at 0x10c22d780>,
#  <gedcom.element.element.Element at 0x10c22db70>,
#  <gedcom.element.element.Element at 0x10c22df60>,
#  <gedcom.element.element.Element at 0x10c230390>,
#  <gedcom.element.element.Element at 0x10c230780>,
#  <gedcom.element.element.Element at 0x10c230b70>,
#  <gedcom.element.element.Element at 0x10c230f60>,
#  <gedcom.element.element.Element at 0x10c233390>,
#  <gedcom.element.element.Element at 0x10c233780>,
#  <gedcom.element.element.Element at 0x10c233b70>,
#  <gedcom.element.element.Element at 0x10c233f60>,
#  <gedcom.element.element.Element at 0x10c235390>,
#  <gedcom.element.element.Element at 0x10c235780>,
#  <gedcom.element.element.Element at 0x10c235b70>,
#  <gedcom.element.element.Element at 0x10c235f60>,
#  <gedcom.element.element.Element at 0x10c238390>,
#  <gedcom.element.element.Element at 0x10c238780>,
#  <gedcom.element.element.Element at 0x10c238b70>,
#  <gedcom.element.element.Element at 0x10c238f98>,
#  <gedcom.element.element.Element at 0x10c23b3c8>,
#  <gedcom.element.element.Element at 0x10c23b7b8>,
#  <gedcom.element.element.Element at 0x10c23bba8>,
#  <gedcom.element.element.Element at 0x10c23bf98>,
#  <gedcom.element.element.Element at 0x10c23d3c8>,
#  <gedcom.element.element.Element at 0x10c23d7b8>,
#  <gedcom.element.element.Element at 0x10c23dba8>,
#  <gedcom.element.element.Element at 0x10c23df98>,
#  <gedcom.element.element.Element at 0x10c2403c8>,
#  <gedcom.element.element.Element at 0x10c2407b8>,
#  <gedcom.element.element.Element at 0x10c240ba8>,
#  <gedcom.element.element.Element at 0x10c240f98>,
#  <gedcom.element.element.Element at 0x10c2433c8>,
#  <gedcom.element.element.Element at 0x10c2437b8>,
#  <gedcom.element.element.Element at 0x10c243ba8>,
#  <gedcom.element.element.Element at 0x10c243f98>,
#  <gedcom.element.element.Element at 0x10c2453c8>,
#  <gedcom.element.element.Element at 0x10c2457b8>,
#  <gedcom.element.element.Element at 0x10c245ba8>,
#  <gedcom.element.element.Element at 0x10c248080>,
#  <gedcom.element.element.Element at 0x10c248470>,
#  <gedcom.element.element.Element at 0x10c248860>,
#  <gedcom.element.element.Element at 0x10c248c50>,
#  <gedcom.element.element.Element at 0x10c24c128>,
#  <gedcom.element.element.Element at 0x10c24c518>,
#  <gedcom.element.element.Element at 0x10c24c908>,
#  <gedcom.element.element.Element at 0x10c24ccc0>]

# %%
#use empty list to collect data
data = []
# Iterate through all root child elements
for element in root_child_elements:

    # Is the `element` an actual `IndividualElement`? (Allows usage of extra functions such as `surname_match` and `get_name`.)
    if isinstance(element, IndividualElement):
        
        if element.is_individual:
            INDI = element.get_pointer()
            (first, last) = element.get_name()
            sex = element.get_gender()
            DOB_simple = element.get_birth_year()
            DOD_simple = element.get_death_year()
            #ancestors = gedcom_parser.get_ancestors(element)
            parents = gedcom_parser.get_parents(element)
          #  if gedcom_parser.get_parents(element) is '[]':
           #     print("NaN")
        
            #DOB = element.get_birth_data()  ##this includes source info and full date
            #DOD = element.get_death_data()  ##ditto  
            
            #append all at once so that it can go from list to DF
            data.append([first, last, sex, DOB_simple, DOD_simple, parents, INDI])

# %%
data
# Out:
# [['James Garrett',
#   'Biddle',
#   'M',
#   1868,
#   1947,
#   [<gedcom.element.individual.IndividualElement at 0x10bda7f60>,
#    <gedcom.element.individual.IndividualElement at 0x10bd9f1d0>],
#   '@P1@'],
#  ['Mary',
#   'Hutton',
#   'F',
#   1869,
#   1925,
#   [<gedcom.element.individual.IndividualElement at 0x10be53278>,
#    <gedcom.element.individual.IndividualElement at 0x10be414a8>],
#   '@P2@'],
#  ['Mary',
#   'Hewes',
#   'F',
#   1842,
#   1874,
#   [<gedcom.element.individual.IndividualElement at 0x10be64278>,
#    <gedcom.element.individual.IndividualElement at 0x10be62898>],
#   '@P3@'],
#  ['John William',
#   'Biddle',
#   'M',
#   1835,
#   1916,
#   [<gedcom.element.individual.IndividualElement at 0x10be36e48>,
#    <gedcom.element.individual.IndividualElement at 0x10be39d68>],
#   '@P4@'],
#  ['Addison Hutton',
#   'Biddle',
#   'M',
#   1903,
#   1912,
#   [<gedcom.element.individual.IndividualElement at 0x10bd746d8>,
#    <gedcom.element.individual.IndividualElement at 0x10bd8a4e0>],
#   '@P5@'],
#  ['Ruth',
#   'Biddle',
#   'F',
#   1906,
#   1969,
#   [<gedcom.element.individual.IndividualElement at 0x10bd746d8>,
#    <gedcom.element.individual.IndividualElement at 0x10bd8a4e0>],
#   '@P6@'],
#  ['Rebecca Hutton',
#   'Biddle',
#   'F',
#   1901,
#   1991,
#   [<gedcom.element.individual.IndividualElement at 0x10bd746d8>,
#    <gedcom.element.individual.IndividualElement at 0x10bd8a4e0>],
#   '@P7@'],
#  ['Elizabeth Rebecca',
#   'Biddle',
#   'F',
#   1897,
#   1975,
#   [<gedcom.element.individual.IndividualElement at 0x10bd746d8>,
#    <gedcom.element.individual.IndividualElement at 0x10bd8a4e0>],
#   '@P8@'],
#  ['Dorothy',
#   'Biddle',
#   'F',
#   1900,
#   1985,
#   [<gedcom.element.individual.IndividualElement at 0x10bd746d8>,
#    <gedcom.element.individual.IndividualElement at 0x10bd8a4e0>],
#   '@P9@'],
#  ['Mary Hewes',
#   'Biddle',
#   'F',
#   1898,
#   1963,
#   [<gedcom.element.individual.IndividualElement at 0x10bd746d8>,
#    <gedcom.element.individual.IndividualElement at 0x10bd8a4e0>],
#   '@P10@'],
#  ['Ruth Ella', 'Chambers', 'F', 1870, 1948, [], '@P11@'],
#  ['William', 'Biddle', 'M', 1806, 1887, [], '@P12@'],
#  ['Elizabeth Cesson', 'Biddle', 'F', -1, 1881, [], '@P13@'],
#  ['William',
#   'Biddle',
#   'M',
#   1863,
#   1948,
#   [<gedcom.element.individual.IndividualElement at 0x10bda7f60>,
#    <gedcom.element.individual.IndividualElement at 0x10bd9f1d0>],
#   '@P14@'],
#  ['Rebecca', 'Savery', 'F', 1836, 1902, [], '@P15@'],
#  ['Addison',
#   'Hutton',
#   'M',
#   1834,
#   1916,
#   [<gedcom.element.individual.IndividualElement at 0x10bfa8240>,
#    <gedcom.element.individual.IndividualElement at 0x10bfadd30>],
#   '@P16@'],
#  ['Sarah S', 'Garrett', 'F', 1819, 1853, [], '@P17@'],
#  ['Edward C', 'Hewes', 'M', 1821, 1880, [], '@P18@'],
#  ['Margaret Cope',
#   'James',
#   'F',
#   1935,
#   1979,
#   [<gedcom.element.individual.IndividualElement at 0x10be8f710>,
#    <gedcom.element.individual.IndividualElement at 0x10be0e940>],
#   '@P19@'],
#  ['Caroline Biddle',
#   'James',
#   'F',
#   1932,
#   2012,
#   [<gedcom.element.individual.IndividualElement at 0x10be8f710>,
#    <gedcom.element.individual.IndividualElement at 0x10be0e940>],
#   '@P20@'],
#  ['Mary Hutton',
#   'James',
#   'F',
#   1930,
#   2002,
#   [<gedcom.element.individual.IndividualElement at 0x10be8f710>,
#    <gedcom.element.individual.IndividualElement at 0x10be0e940>],
#   '@P21@'],
#  ['John Robert',
#   'James',
#   'M',
#   1938,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10be8f710>,
#    <gedcom.element.individual.IndividualElement at 0x10be0e940>],
#   '@P22@'],
#  ['John Robert',
#   'James',
#   'M',
#   1895,
#   1992,
#   [<gedcom.element.individual.IndividualElement at 0x10c01a208>,
#    <gedcom.element.individual.IndividualElement at 0x10c01f860>],
#   '@P23@'],
#  ['James Biddle',
#   'Yarnall',
#   'M',
#   1926,
#   2009,
#   [<gedcom.element.individual.IndividualElement at 0x10becdeb8>,
#    <gedcom.element.individual.IndividualElement at 0x10bdf8240>],
#   '@P24@'],
#  ['Nancy Hutton',
#   'Yarnall',
#   'F',
#   1928,
#   2004,
#   [<gedcom.element.individual.IndividualElement at 0x10becdeb8>,
#    <gedcom.element.individual.IndividualElement at 0x10bdf8240>],
#   '@P25@'],
#  ['David Robert',
#   'Yarnall',
#   'M',
#   1925,
#   1999,
#   [<gedcom.element.individual.IndividualElement at 0x10becdeb8>,
#    <gedcom.element.individual.IndividualElement at 0x10bdf8240>],
#   '@P26@'],
#  ['David Robert',
#   'Yarnall',
#   'M',
#   1878,
#   1967,
#   [<gedcom.element.individual.IndividualElement at 0x10bfb9208>,
#    <gedcom.element.individual.IndividualElement at 0x10bfb44e0>],
#   '@P27@'],
#  ['David Macowan',
#   'Sinclair',
#   'M',
#   1928,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bf1c860>,
#    <gedcom.element.individual.IndividualElement at 0x10be24400>],
#   '@P28@'],
#  ['Sylvia Buell',
#   'Sinclair',
#   'F',
#   1929,
#   2015,
#   [<gedcom.element.individual.IndividualElement at 0x10bf1c860>,
#    <gedcom.element.individual.IndividualElement at 0x10be24400>],
#   '@P29@'],
#  ['Mary Biddle',
#   'Sinclair',
#   'F',
#   1926,
#   2009,
#   [<gedcom.element.individual.IndividualElement at 0x10bf1c860>,
#    <gedcom.element.individual.IndividualElement at 0x10be24400>],
#   '@P30@'],
#  ['John Biddle',
#   'Sinclair',
#   'M',
#   1935,
#   2019,
#   [<gedcom.element.individual.IndividualElement at 0x10bf1c860>,
#    <gedcom.element.individual.IndividualElement at 0x10be24400>],
#   '@P31@'],
#  ['John Stephens',
#   'Sinclair',
#   'M',
#   1897,
#   1972,
#   [<gedcom.element.individual.IndividualElement at 0x10bfd2a90>,
#    <gedcom.element.individual.IndividualElement at 0x10bfcc048>],
#   '@P32@'],
#  ['Cecilia',
#   'Bradbeer',
#   'F',
#   1930,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bf5c7f0>,
#    <gedcom.element.individual.IndividualElement at 0x10bddef98>],
#   '@P33@'],
#  ['James Biddle',
#   'Bradbeer',
#   'M',
#   1932,
#   2019,
#   [<gedcom.element.individual.IndividualElement at 0x10bf5c7f0>,
#    <gedcom.element.individual.IndividualElement at 0x10bddef98>],
#   '@P34@'],
#  ['Frank Gilbert',
#   'Bradbeer',
#   'M',
#   1887,
#   1935,
#   [<gedcom.element.individual.IndividualElement at 0x10c0a9828>,
#    <gedcom.element.individual.IndividualElement at 0x10c0a35c0>],
#   '@P35@'],
#  ['Thornton Bancroft',
#   'Penfield',
#   'M',
#   1934,
#   2007,
#   [<gedcom.element.individual.IndividualElement at 0x10bf8d550>,
#    <gedcom.element.individual.IndividualElement at 0x10bdc0e48>],
#   '@P36@'],
#  ['Charlotte Elizabeth',
#   'Penfield',
#   'F',
#   1935,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bf8d550>,
#    <gedcom.element.individual.IndividualElement at 0x10bdc0e48>],
#   '@P37@'],
#  ['Thornton Bancroft',
#   'Penfield',
#   'M',
#   1899,
#   1975,
#   [<gedcom.element.individual.IndividualElement at 0x10c08e860>,
#    <gedcom.element.individual.IndividualElement at 0x10c0895f8>],
#   '@P38@'],
#  ['Joel Wright', 'Hutton', 'M', 1811, 1862, [], '@P39@'],
#  ['Ann', 'Mains', 'F', 1812, 1865, [], '@P40@'],
#  ['Sidney S', 'Garrett', 'F', 1851, 1949, [], '@P41@'],
#  ['Edward Smedley', 'Yarnall', 'M', 1846, 1931, [], '@P42@'],
#  ['Kristina Garrett',
#   'Yarnall',
#   'F',
#   1960,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bec0978>,
#    <gedcom.element.individual.IndividualElement at 0x10bfc0470>],
#   '@P43@'],
#  ['Sara Gabrielsen',
#   'Yarnall',
#   'F',
#   1958,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bec0978>,
#    <gedcom.element.individual.IndividualElement at 0x10bfc0470>],
#   '@P44@'],
#  ['Joan Biddle',
#   'Yarnall',
#   'F',
#   1956,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bec0978>,
#    <gedcom.element.individual.IndividualElement at 0x10bfc0470>],
#   '@P45@'],
#  ['Rie',
#   'Gabrielsen',
#   'F',
#   1930,
#   1980,
#   [<gedcom.element.individual.IndividualElement at 0x10c100cf8>],
#   '@P46@'],
#  ['Stephen Garrett',
#   'Yarnall',
#   'M',
#   1957,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bea6d68>,
#    <gedcom.element.individual.IndividualElement at 0x10bfc9668>],
#   '@P47@'],
#  ['James Biddle',
#   'Yarnall',
#   'M',
#   1955,
#   2018,
#   [<gedcom.element.individual.IndividualElement at 0x10bea6d68>,
#    <gedcom.element.individual.IndividualElement at 0x10bfc9668>],
#   '@P48@'],
#  ['Phyllis A.', 'Aspen', 'F', 1929, 2013, [], '@P49@'],
#  ['Alice Elvira', 'Stephens', 'F', 1861, 1933, [], '@P50@'],
#  ['David MaCowan', 'Sinclair', 'M', 1861, 1935, [], '@P51@'],
#  ['Mary Hewes',
#   'Buck',
#   'F',
#   1955,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bfeacc0>,
#    <gedcom.element.individual.IndividualElement at 0x10bf05780>],
#   '@P52@'],
#  ['Alice Sinclair',
#   'Buck',
#   'F',
#   1953,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bfeacc0>,
#    <gedcom.element.individual.IndividualElement at 0x10bf05780>],
#   '@P53@'],
#  ['David Douglass',
#   'Buck',
#   'M',
#   1949,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bfeacc0>,
#    <gedcom.element.individual.IndividualElement at 0x10bf05780>],
#   '@P54@'],
#  ['John Clayton',
#   'Buck',
#   'M',
#   1950,
#   2009,
#   [<gedcom.element.individual.IndividualElement at 0x10bfeacc0>,
#    <gedcom.element.individual.IndividualElement at 0x10bf05780>],
#   '@P55@'],
#  ['Joseph J.', 'Krakora', 'M', 1939, -1, [], '@P56@'],
#  ['Clayton Douglass',
#   'Buck',
#   'M',
#   1923,
#   1986,
#   [<gedcom.element.individual.IndividualElement at 0x10c078710>,
#    <gedcom.element.individual.IndividualElement at 0x10c072a20>],
#   '@P57@'],
#  ['John Christopher',
#   'Carr',
#   'M',
#   1966,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0104a8>,
#    <gedcom.element.individual.IndividualElement at 0x10bef42b0>],
#   '@P58@'],
#  ['Elizabeth Anne',
#   'Carr',
#   'F',
#   1964,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0104a8>,
#    <gedcom.element.individual.IndividualElement at 0x10bef42b0>],
#   '@P59@'],
#  ['Daniel Thaddeus',
#   'Carr',
#   'M',
#   1963,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0104a8>,
#    <gedcom.element.individual.IndividualElement at 0x10bef42b0>],
#   '@P60@'],
#  ['Suzanne Noel',
#   'Carr',
#   'F',
#   1960,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0104a8>,
#    <gedcom.element.individual.IndividualElement at 0x10bef42b0>],
#   '@P61@'],
#  ['Matthew Francis',
#   'Carr',
#   'M',
#   1958,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0104a8>,
#    <gedcom.element.individual.IndividualElement at 0x10bef42b0>],
#   '@P62@'],
#  ['Deborah Ward',
#   'Carr',
#   'F',
#   1957,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0104a8>,
#    <gedcom.element.individual.IndividualElement at 0x10bef42b0>],
#   '@P63@'],
#  ['Sylvia Stephens',
#   'Carr',
#   'F',
#   1956,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0104a8>,
#    <gedcom.element.individual.IndividualElement at 0x10bef42b0>],
#   '@P64@'],
#  ['Stephen Kerry',
#   'Carr',
#   'M',
#   1955,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0104a8>,
#    <gedcom.element.individual.IndividualElement at 0x10bef42b0>],
#   '@P65@'],
#  ['Kathleen Mary',
#   'Carr',
#   'F',
#   1954,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0104a8>,
#    <gedcom.element.individual.IndividualElement at 0x10bef42b0>],
#   '@P66@'],
#  ['Stephen Kerry', 'Carr', 'M', 1930, -1, [], '@P67@'],
#  ['Milo', 'Berking', '', 1925, 2007, [], '@P68@'],
#  ['John Edwin', 'James', 'M', 1864, 1938, [], '@P69@'],
#  ['Mary Hughes', 'Cope', 'F', 1865, 1954, [], '@P70@'],
#  ['Janet Biddle',
#   'Herrin',
#   'F',
#   1965,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c028b00>,
#    <gedcom.element.individual.IndividualElement at 0x10be6f400>],
#   '@P71@'],
#  ['Gareld Robertson', 'Herrin', 'M', 1929, 2005, [], '@P72@'],
#  ['Kenneth James',
#   'Herrin',
#   'M',
#   1962,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c028b00>,
#    <gedcom.element.individual.IndividualElement at 0x10be6f400>],
#   '@P73@'],
#  ['John Robertson',
#   'Herrin',
#   'M',
#   1960,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c028b00>,
#    <gedcom.element.individual.IndividualElement at 0x10be6f400>],
#   '@P74@'],
#  ['Mary Thayer',
#   'Herrin',
#   'F',
#   1958,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c028b00>,
#    <gedcom.element.individual.IndividualElement at 0x10be6f400>],
#   '@P75@'],
#  ['Frederic Valerius',
#   'Hetzel',
#   'M',
#   1930,
#   2005,
#   [<gedcom.element.individual.IndividualElement at 0x10c151828>,
#    <gedcom.element.individual.IndividualElement at 0x10c1513c8>],
#   '@P76@'],
#  ['Sylvia Biddle',
#   'Hetzel',
#   'F',
#   1959,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0396a0>,
#    <gedcom.element.individual.IndividualElement at 0x10be7c710>],
#   '@P77@'],
#  ['Frederic James',
#   'Hetzel',
#   'M',
#   1957,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0396a0>,
#    <gedcom.element.individual.IndividualElement at 0x10be7c710>],
#   '@P78@'],
#  ['Robert Wills',
#   'Hetzel',
#   'M',
#   1954,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0396a0>,
#    <gedcom.element.individual.IndividualElement at 0x10be7c710>],
#   '@P79@'],
#  ['Elizabeth Barr',
#   'Holt',
#   'F',
#   1968,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0490b8>,
#    <gedcom.element.individual.IndividualElement at 0x10be64c18>],
#   '@P80@'],
#  ['John Harris',
#   'Holt',
#   'M',
#   1965,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0490b8>,
#    <gedcom.element.individual.IndividualElement at 0x10be64c18>],
#   '@P81@'],
#  ['Richard James',
#   'Holt',
#   'M',
#   1960,
#   1960,
#   [<gedcom.element.individual.IndividualElement at 0x10c0490b8>,
#    <gedcom.element.individual.IndividualElement at 0x10be64c18>],
#   '@P82@'],
#  ['Harris Richard',
#   'Holt',
#   'M',
#   1934,
#   2009,
#   [<gedcom.element.individual.IndividualElement at 0x10c169b38>,
#    <gedcom.element.individual.IndividualElement at 0x10c166518>],
#   '@P83@'],
#  ['Cynthia Biddle',
#   'Holt',
#   'F',
#   1962,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0490b8>,
#    <gedcom.element.individual.IndividualElement at 0x10be64c18>],
#   '@P84@'],
#  ['Margot',
#   'Sinclair',
#   'F',
#   1962,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bee63c8>,
#    <gedcom.element.individual.IndividualElement at 0x10c060e48>],
#   '@P85@'],
#  ['Craig Widmann',
#   'Sinclair',
#   'M',
#   1959,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bee63c8>,
#    <gedcom.element.individual.IndividualElement at 0x10c060e48>],
#   '@P86@'],
#  ['Timothy Biddle',
#   'Sinclair',
#   'M',
#   1958,
#   1968,
#   [<gedcom.element.individual.IndividualElement at 0x10bee63c8>,
#    <gedcom.element.individual.IndividualElement at 0x10c060e48>],
#   '@P87@'],
#  ['Susan', 'Widmann', 'F', 1932, -1, [], '@P88@'],
#  ['Anne Zeis',
#   'Sinclair',
#   'F',
#   1965,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bf14b38>,
#    <gedcom.element.individual.IndividualElement at 0x10c06df28>],
#   '@P89@'],
#  ['David Rickards',
#   'Sinclair',
#   'M',
#   1962,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bf14b38>,
#    <gedcom.element.individual.IndividualElement at 0x10c06df28>],
#   '@P90@'],
#  ['John Biddle',
#   'Sinclair',
#   'M',
#   1960,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bf14b38>,
#    <gedcom.element.individual.IndividualElement at 0x10c06df28>],
#   '@P91@'],
#  ['Lynn', 'Rickards', 'F', 1935, -1, [], '@P92@'],
#  ['Alice Hounsfield', 'du Pont', 'F', 1891, 1967, [], '@P93@'],
#  ['Clayton Douglass', 'Buck', 'M', 1890, 1965, [], '@P94@'],
#  ['Jeremiah Clayton',
#   'Buck',
#   'M',
#   1978,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bfe2908>,
#    <gedcom.element.individual.IndividualElement at 0x10c07ecc0>],
#   '@P95@'],
#  ['Magnolia Hannah',
#   'Buck',
#   'F',
#   1975,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bfe2908>,
#    <gedcom.element.individual.IndividualElement at 0x10c07ecc0>],
#   '@P96@'],
#  ['Gayle Maureen', 'Hannah', 'F', 1954, -1, [], '@P97@'],
#  ['Kathryn Anne',
#   'Krakora',
#   'F',
#   1965,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bfe5da0>,
#    <gedcom.element.individual.IndividualElement at 0x10c0809b0>],
#   '@P98@'],
#  ['Diane Brace', 'Conner', 'F', 1938, -1, [], '@P99@'],
#  ['Leigh Biddle',
#   'James',
#   'F',
#   1980,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10be8aba8>,
#    <gedcom.element.individual.IndividualElement at 0x10c0864e0>],
#   '@P100@'],
#  ['Christina Ballard',
#   'James',
#   'F',
#   1978,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10be8aba8>,
#    <gedcom.element.individual.IndividualElement at 0x10c0864e0>],
#   '@P101@'],
#  ['Dixie Lee', 'Donaldson', 'F', 1945, -1, [], '@P102@'],
#  ['John Robert',
#   'James',
#   'M',
#   1974,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10be8aba8>,
#    <gedcom.element.individual.IndividualElement at 0x10c0864e0>],
#   '@P103@'],
#  ['Martha Mee', 'Martin', 'F', 1868, 1954, [], '@P104@'],
#  ['Thornton Bancroft', 'Penfield', 'M', 1867, 1958, [], '@P105@'],
#  ['Janet Richardson', 'German', 'F', 1916, 2004, [], '@P106@'],
#  ['Diane', 'Depp', '', 1947, -1, [], '@P107@'],
#  ['Elizabeth', 'Few', 'F', 1939, -1, [], '@P108@'],
#  ['Cecilia Henrietta', 'Jones', 'F', 1865, 1915, [], '@P109@'],
#  ['Frank', 'Bradbeer', 'M', 1865, 1898, [], '@P110@'],
#  ['Erica Maria Smit',
#   'Sibinga',
#   'F',
#   1962,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0b5978>,
#    <gedcom.element.individual.IndividualElement at 0x10bf3b240>],
#   '@P111@'],
#  ['Nicholas Ernst Smit',
#   'Sibinga',
#   'M',
#   1959,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0b5978>,
#    <gedcom.element.individual.IndividualElement at 0x10bf3b240>],
#   '@P112@'],
#  ['Derek Johannes Smit',
#   'Sibinga',
#   'M',
#   1961,
#   1961,
#   [<gedcom.element.individual.IndividualElement at 0x10c0b5978>,
#    <gedcom.element.individual.IndividualElement at 0x10bf3b240>],
#   '@P113@'],
#  ['Michael Frank Smit',
#   'Sibinga',
#   'M',
#   1957,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0b5978>,
#    <gedcom.element.individual.IndividualElement at 0x10bf3b240>],
#   '@P114@'],
#  ['Maarten', 'Sibinga', 'M', 1927, 2003, [], '@P115@'],
#  ['James Biddle',
#   'Bradbeer',
#   'M',
#   1962,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bf4e0f0>,
#    <gedcom.element.individual.IndividualElement at 0x10c0ba320>],
#   '@P116@'],
#  ['Mary Florence', 'Buckley', 'F', 1935, 1999, [], '@P117@'],
#  ['Rebecca Hutton',
#   'Bradbeer',
#   'U',
#   1966,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bf4e0f0>,
#    <gedcom.element.individual.IndividualElement at 0x10c0ba320>],
#   '@P118@'],
#  ['Arthur Edwin',
#   'James',
#   'M',
#   1897,
#   1989,
#   [<gedcom.element.individual.IndividualElement at 0x10c01a208>,
#    <gedcom.element.individual.IndividualElement at 0x10c01f860>],
#   '@P119@'],
#  ['William Cope',
#   'James',
#   'M',
#   1893,
#   1960,
#   [<gedcom.element.individual.IndividualElement at 0x10c01a208>,
#    <gedcom.element.individual.IndividualElement at 0x10c01f860>],
#   '@P120@'],
#  ['Margaret Sharpless',
#   'James',
#   'F',
#   1891,
#   1934,
#   [<gedcom.element.individual.IndividualElement at 0x10c01a208>,
#    <gedcom.element.individual.IndividualElement at 0x10c01f860>],
#   '@P121@'],
#  ['Lauretta Phillips',
#   'James',
#   'F',
#   1890,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c01a208>,
#    <gedcom.element.individual.IndividualElement at 0x10c01f860>],
#   '@P122@'],
#  ['William',
#   'Sinclair',
#   'M',
#   1896,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bfd2a90>,
#    <gedcom.element.individual.IndividualElement at 0x10bfcc048>],
#   '@P123@'],
#  ['Sylvia',
#   'Sinclair',
#   'F',
#   1894,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bfd2a90>,
#    <gedcom.element.individual.IndividualElement at 0x10bfcc048>],
#   '@P124@'],
#  ['Jessie Cecilia',
#   'Bradbeer',
#   'F',
#   1893,
#   1979,
#   [<gedcom.element.individual.IndividualElement at 0x10c0a9828>,
#    <gedcom.element.individual.IndividualElement at 0x10c0a35c0>],
#   '@P125@'],
#  ['Albert Frederick',
#   'Bradbeer',
#   'M',
#   1890,
#   1963,
#   [<gedcom.element.individual.IndividualElement at 0x10c0a9828>,
#    <gedcom.element.individual.IndividualElement at 0x10c0a35c0>],
#   '@P126@'],
#  ['Paul Livingstone',
#   'Penfield',
#   'M',
#   1901,
#   1992,
#   [<gedcom.element.individual.IndividualElement at 0x10c08e860>,
#    <gedcom.element.individual.IndividualElement at 0x10c0895f8>],
#   '@P127@'],
#  ['Charlotte Martin',
#   'Penfield',
#   'F',
#   1895,
#   1979,
#   [<gedcom.element.individual.IndividualElement at 0x10c08e860>,
#    <gedcom.element.individual.IndividualElement at 0x10c0895f8>],
#   '@P128@'],
#  ['Winifred M',
#   'Atwater',
#   'F',
#   1881,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c08e860>,
#    <gedcom.element.individual.IndividualElement at 0x10c0895f8>],
#   '@P129@'],
#  ['Rebecca Elizabeth',
#   'Gosselink',
#   'F',
#   1967,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0fbd30>,
#    <gedcom.element.individual.IndividualElement at 0x10bf81ba8>],
#   '@P130@'],
#  ['Robert George',
#   'Gosselink',
#   'M',
#   1964,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0fbd30>,
#    <gedcom.element.individual.IndividualElement at 0x10bf81ba8>],
#   '@P131@'],
#  ['James Bancroft',
#   'Gosselink',
#   'M',
#   1963,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0fbd30>,
#    <gedcom.element.individual.IndividualElement at 0x10bf81ba8>],
#   '@P132@'],
#  ['Charles George', 'Gosselink', 'M', 1935, -1, [], '@P133@'],
#  ['Hans', 'Gabrielsen', 'M', 1900, -1, [], '@P134@'],
#  ['Evan Robert',
#   'Ma',
#   'M',
#   1992,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c101e10>,
#    <gedcom.element.individual.IndividualElement at 0x10bfbddd8>],
#   '@P135@'],
#  ['Rie Yarnall',
#   'Ma',
#   'F',
#   1987,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c101e10>,
#    <gedcom.element.individual.IndividualElement at 0x10bfbddd8>],
#   '@P136@'],
#  ['Robert Tien', 'Ma', 'M', 1959, -1, [], '@P137@'],
#  ['Rachel Yarnall',
#   'Sanders',
#   'F',
#   1988,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c105cf8>,
#    <gedcom.element.individual.IndividualElement at 0x10bfbd898>],
#   '@P138@'],
#  ['Gabriel Yarnall',
#   'Sanders',
#   'M',
#   1985,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c105cf8>,
#    <gedcom.element.individual.IndividualElement at 0x10bfbd898>],
#   '@P139@'],
#  ['David Alan', 'Sanders', 'M', 1942, -1, [], '@P140@'],
#  ['Owen',
#   'Sibinga',
#   'M',
#   2005,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0abf98>,
#    <gedcom.element.individual.IndividualElement at 0x10bfbbc18>],
#   '@P141@'],
#  ['Tyche Eva',
#   'Sibinga',
#   'F',
#   1995,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0abf98>,
#    <gedcom.element.individual.IndividualElement at 0x10bfbbc18>],
#   '@P142@'],
#  ['James Garrett',
#   'Sibinga',
#   'M',
#   1991,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0abf98>,
#    <gedcom.element.individual.IndividualElement at 0x10bfbbc18>],
#   '@P143@'],
#  ['Nathaniel Alexander',
#   'Sibinga',
#   'M',
#   1989,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0abf98>,
#    <gedcom.element.individual.IndividualElement at 0x10bfbbc18>],
#   '@P144@'],
#  ['Dianne', 'DuBois', 'F', -1, -1, [], '@P145@'],
#  ['Elizabeth Claire',
#   'Yarnall',
#   'F',
#   2003,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bfc3908>,
#    <gedcom.element.individual.IndividualElement at 0x10c10bac8>],
#   '@P146@'],
#  ['Rebecca Nicole',
#   'Yarnall',
#   'F',
#   2003,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bfc3908>,
#    <gedcom.element.individual.IndividualElement at 0x10c10bac8>],
#   '@P147@'],
#  ['Sidney Paige',
#   'Yarnall',
#   'F',
#   2001,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bfc3908>,
#    <gedcom.element.individual.IndividualElement at 0x10c10bac8>],
#   '@P148@'],
#  ['Elizabeth', 'Mapes', 'F', 1961, -1, [], '@P149@'],
#  ['Carly', 'Klapp', 'F', -1, -1, [], '@P150@'],
#  ['Kristine', 'Hill', 'F', -1, -1, [], '@P151@'],
#  ['Thomas Garrett',
#   'Buck',
#   'M',
#   1984,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bfdd9e8>,
#    <gedcom.element.individual.IndividualElement at 0x10c10eac8>],
#   '@P152@'],
#  ['Nancy E.', 'Miller', 'F', 1954, -1, [], '@P153@'],
#  ['Thaddeus Chase',
#   'Buck',
#   'M',
#   1976,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bfdd9e8>,
#    <gedcom.element.individual.IndividualElement at 0x10c110898>],
#   '@P154@'],
#  ['Shelli I.', 'Chase', 'F', 1953, -1, [], '@P155@'],
#  ['John Garrett',
#   'DeCandia',
#   'M',
#   1989,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c111a90>,
#    <gedcom.element.individual.IndividualElement at 0x10bfdd3c8>],
#   '@P156@'],
#  ['Michael Douglass',
#   'DeCandia',
#   'M',
#   1986,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c111a90>,
#    <gedcom.element.individual.IndividualElement at 0x10bfdd3c8>],
#   '@P157@'],
#  ['Michael John', 'DeCandia', 'M', 1951, -1, [], '@P158@'],
#  ['David', 'Quint', 'M', -1, -1, [], '@P159@'],
#  ['Joseph Samuel',
#   'Buck',
#   'M',
#   1984,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c111fd0>,
#    <gedcom.element.individual.IndividualElement at 0x10bfdb908>],
#   '@P160@'],
#  ['Ellie Mae',
#   'McDonald',
#   'F',
#   1979,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c115be0>,
#    <gedcom.element.individual.IndividualElement at 0x10bfdb908>],
#   '@P161@'],
#  ['Glenn', 'McDonald', 'M', -1, -1, [], '@P162@'],
#  ['Lindy',
#   'Sinclair',
#   'F',
#   2000,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c05b358>,
#    <gedcom.element.individual.IndividualElement at 0x10c116630>],
#   '@P163@'],
#  ['Nan M', 'Octeau', 'F', 1966, -1, [], '@P164@'],
#  ['Jason Andrew',
#   'Mannka',
#   'M',
#   1994,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c11b358>,
#    <gedcom.element.individual.IndividualElement at 0x10c058278>],
#   '@P165@'],
#  ['Christopher Scott',
#   'Mannka',
#   'M',
#   1994,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c11b358>,
#    <gedcom.element.individual.IndividualElement at 0x10c058278>],
#   '@P166@'],
#  ['Peter James',
#   'Mannka',
#   'M',
#   1991,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c11b358>,
#    <gedcom.element.individual.IndividualElement at 0x10c058278>],
#   '@P167@'],
#  ['Scott Daniel', 'Mannka', 'M', 1960, -1, [], '@P168@'],
#  ['Karl Bryn',
#   'Heavenrich',
#   'M',
#   1993,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c1207b8>,
#    <gedcom.element.individual.IndividualElement at 0x10c00d0f0>],
#   '@P169@'],
#  ['Jessica Anne',
#   'Heavenrich',
#   'F',
#   1990,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c1207b8>,
#    <gedcom.element.individual.IndividualElement at 0x10c00d0f0>],
#   '@P170@'],
#  ['Jeb Sinclair',
#   'Heavenrich',
#   'M',
#   1988,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c1207b8>,
#    <gedcom.element.individual.IndividualElement at 0x10c00d0f0>],
#   '@P171@'],
#  ['Walter', 'Heavenrich', 'M', 1951, -1, [], '@P172@'],
#  ['Debora', '', 'F', -1, -1, [], '@P173@'],
#  ['Brendan Connor',
#   'Carr',
#   'M',
#   1990,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c008c18>,
#    <gedcom.element.individual.IndividualElement at 0x10c12a668>],
#   '@P174@'],
#  ['Ryan Samuel',
#   'Carr',
#   'M',
#   1985,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c008c18>,
#    <gedcom.element.individual.IndividualElement at 0x10c12a668>],
#   '@P175@'],
#  ['Sean Kerry',
#   'Carr',
#   'M',
#   1983,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c008c18>,
#    <gedcom.element.individual.IndividualElement at 0x10c12a668>],
#   '@P176@'],
#  ['Kari Beth', 'Olson', 'F', 1956, -1, [], '@P177@'],
#  ['Emma Hewes',
#   'Rubenstein',
#   'F',
#   1991,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c131278>,
#    <gedcom.element.individual.IndividualElement at 0x10c006860>],
#   '@P178@'],
#  ['Anne Chandler',
#   'Rubenstein',
#   'F',
#   1988,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c131278>,
#    <gedcom.element.individual.IndividualElement at 0x10c006860>],
#   '@P179@'],
#  ['Katelyn Sinclair',
#   'Rubenstein',
#   'F',
#   1986,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c131278>,
#    <gedcom.element.individual.IndividualElement at 0x10c006860>],
#   '@P180@'],
#  ['Donald Paul', 'Rubenstein', 'M', 1958, -1, [], '@P181@'],
#  ['William Ward',
#   'Adamy',
#   'M',
#   1990,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c136a90>,
#    <gedcom.element.individual.IndividualElement at 0x10c003940>],
#   '@P182@'],
#  ['Julia Sinclair',
#   'Adamy',
#   'F',
#   1988,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c136a90>,
#    <gedcom.element.individual.IndividualElement at 0x10c003940>],
#   '@P183@'],
#  ['Paul Kendrick', 'Adamy', 'M', 1957, -1, [], '@P184@'],
#  ['Hillary Hayes',
#   'Carr',
#   'F',
#   1991,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0018d0>,
#    <gedcom.element.individual.IndividualElement at 0x10c138c50>],
#   '@P185@'],
#  ['Ian Collins',
#   'Carr',
#   'M',
#   1988,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0018d0>,
#    <gedcom.element.individual.IndividualElement at 0x10c138c50>],
#   '@P186@'],
#  ['Matthew Francis',
#   'Carr',
#   'M',
#   1986,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0018d0>,
#    <gedcom.element.individual.IndividualElement at 0x10c138c50>],
#   '@P187@'],
#  ['Melissa', 'Golder', 'F', 1960, -1, [], '@P188@'],
#  ['Hannah Sinclair',
#   'Weber',
#   'F',
#   1996,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c13b9b0>,
#    <gedcom.element.individual.IndividualElement at 0x10bffe160>],
#   '@P189@'],
#  ['Sarah Noel',
#   'Weber',
#   'F',
#   1994,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c13b9b0>,
#    <gedcom.element.individual.IndividualElement at 0x10bffe160>],
#   '@P190@'],
#  ['Christian Dietrich', 'Weber', 'M', 1964, -1, [], '@P191@'],
#  ['Kirsti Lynn',
#   'Carr',
#   'F',
#   1996,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bffb2e8>,
#    <gedcom.element.individual.IndividualElement at 0x10c1403c8>],
#   '@P192@'],
#  ['Siri Marie',
#   'Carr',
#   'F',
#   1993,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bffb2e8>,
#    <gedcom.element.individual.IndividualElement at 0x10c1403c8>],
#   '@P193@'],
#  ['Kari Ellen', 'Kaalstad', 'F', 1963, -1, [], '@P194@'],
#  ['Sopia Elizabeth',
#   'Gennusa',
#   'F',
#   2003,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c141128>,
#    <gedcom.element.individual.IndividualElement at 0x10bff8470>],
#   '@P195@'],
#  ['Robert Thomas', 'Riley', 'M', 1962, -1, [], '@P196@'],
#  ['Domenick', 'Gennusa', 'M', 1973, -1, [], '@P197@'],
#  ['Mary Sylvia',
#   'Carr',
#   'F',
#   2007,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bff7278>,
#    <gedcom.element.individual.IndividualElement at 0x10c145860>],
#   '@P198@'],
#  ['Lila Jane',
#   'Carr',
#   'F',
#   2003,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bff7278>,
#    <gedcom.element.individual.IndividualElement at 0x10c145860>],
#   '@P199@'],
#  ['Stephen Erikson',
#   'Carr',
#   'M',
#   2001,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10bff7278>,
#    <gedcom.element.individual.IndividualElement at 0x10c145860>],
#   '@P200@'],
#  ['Abigail Josephine', 'Gouverneur', 'F', 1960, -1, [], '@P201@'],
#  ['Sarah Elizabeth', 'Fisher', 'F', 1966, -1, [], '@P202@'],
#  ['Elizabeth Smith',
#   'Sinclair',
#   'F',
#   1997,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c06b630>,
#    <gedcom.element.individual.IndividualElement at 0x10c14a240>],
#   '@P203@'],
#  ['John Biddle',
#   'Sinclair',
#   'M',
#   1995,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c06b630>,
#    <gedcom.element.individual.IndividualElement at 0x10c14a240>],
#   '@P204@'],
#  ['Karen', 'Smith', 'F', 1961, -1, [], '@P205@'],
#  ['Barbara', 'Hartmann', 'F', -1, -1, [], '@P206@'],
#  ['Ian Rickards',
#   'Sinclair',
#   'M',
#   1993,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c068860>,
#    <gedcom.element.individual.IndividualElement at 0x10c14cba8>],
#   '@P207@'],
#  ['Emily Hutton',
#   'Sinclair',
#   'F',
#   1991,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c068860>,
#    <gedcom.element.individual.IndividualElement at 0x10c14cba8>],
#   '@P208@'],
#  ['Peggy', 'Soder', 'F', 1963, -1, [], '@P209@'],
#  ['Ada Marie',
#   'Sinclair',
#   'F',
#   -1,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c14c208>,
#    <gedcom.element.individual.IndividualElement at 0x10c14f358>],
#   '@P210@'],
#  ['Elizabeth', '', 'F', -1, -1, [], '@P211@'],
#  ['Adalynn Zeis',
#   'Griesser',
#   'F',
#   2000,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c14ff28>,
#    <gedcom.element.individual.IndividualElement at 0x10c065780>],
#   '@P212@'],
#  ['Johan Patrick',
#   'Griesser',
#   'M',
#   1998,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c14ff28>,
#    <gedcom.element.individual.IndividualElement at 0x10c065780>],
#   '@P213@'],
#  ['Hans Patrick', 'Griesser', 'M', 1961, -1, [], '@P214@'],
#  ['Rebecca Louise', 'Wills', 'F', -1, -1, [], '@P215@'],
#  ['Theodore Brinton', 'Hetzel', 'M', -1, -1, [], '@P216@'],
#  ['Skyler Krieg',
#   'Graham',
#   'M',
#   1994,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c03fdd8>,
#    <gedcom.element.individual.IndividualElement at 0x10c152668>],
#   '@P217@'],
#  ['Gavin Graham',
#   'Hetzel',
#   'M',
#   2002,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c03fdd8>,
#    <gedcom.element.individual.IndividualElement at 0x10c152668>],
#   '@P218@'],
#  ['Judy', 'Graham', 'F', 1970, -1, [], '@P219@'],
#  ['Benjamin Will',
#   'Hetzel',
#   'M',
#   1993,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c03fdd8>,
#    <gedcom.element.individual.IndividualElement at 0x10c156198>],
#   '@P220@'],
#  ['Laura Katherine', 'Tyree', 'F', 1965, -1, [], '@P221@'],
#  ['Ronda Leigh', 'Porter', 'F', 1955, -1, [], '@P222@'],
#  ['Andrea',
#   'Cipparrone',
#   'M',
#   1990,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c1574a8>,
#    <gedcom.element.individual.IndividualElement at 0x10c03a940>],
#   '@P223@'],
#  ['Giacomo',
#   'Cipparrone',
#   'M',
#   1988,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c1574a8>,
#    <gedcom.element.individual.IndividualElement at 0x10c03a940>],
#   '@P224@'],
#  ['Salvatore', 'Cipparrone', 'M', 1946, -1, [], '@P225@'],
#  ['Meaghan Caroline',
#   'McCarthy',
#   'F',
#   1997,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c15a9e8>,
#    <gedcom.element.individual.IndividualElement at 0x10c0353c8>],
#   '@P226@'],
#  ['Eric James',
#   'McCarthy',
#   'M',
#   1993,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c15a9e8>,
#    <gedcom.element.individual.IndividualElement at 0x10c0353c8>],
#   '@P227@'],
#  ['Matthew Ryan',
#   'McCarthy',
#   'M',
#   1991,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c15a9e8>,
#    <gedcom.element.individual.IndividualElement at 0x10c0353c8>],
#   '@P228@'],
#  ['David Michael', 'McCarthy', 'M', 1954, -1, [], '@P229@'],
#  ['Laura Anne',
#   'Herrin',
#   'F',
#   1992,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c02f1d0>,
#    <gedcom.element.individual.IndividualElement at 0x10c15ceb8>],
#   '@P230@'],
#  ['Andrea Love',
#   'Herrin',
#   'F',
#   1986,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c02f1d0>,
#    <gedcom.element.individual.IndividualElement at 0x10c15ceb8>],
#   '@P231@'],
#  ['Lisa', 'Baron', 'F', 1985, -1, [], '@P232@'],
#  ['Deborah Love', 'Morin', 'F', 1954, -1, [], '@P233@'],
#  ['Aimee Renee', 'Allen', 'F', 1965, -1, [], '@P234@'],
#  ['Reilly Caroline',
#   'Smith',
#   'F',
#   2016,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c161b00>,
#    <gedcom.element.individual.IndividualElement at 0x10c15c470>],
#   '@P235@'],
#  ['Justin', 'Smith', 'M', -1, -1, [], '@P236@'],
#  ['Eirwen Jane',
#   'Cook',
#   'F',
#   2019,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c1642b0>,
#    <gedcom.element.individual.IndividualElement at 0x10c15aef0>],
#   '@P237@'],
#  ['Joshua', 'Cook', 'M', -1, -1, [], '@P238@'],
#  ['Etta Hutton',
#   'Partridge',
#   'F',
#   2002,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c164fd0>,
#    <gedcom.element.individual.IndividualElement at 0x10c025f98>],
#   '@P239@'],
#  ['Garrett Robertson',
#   'Partridge',
#   'M',
#   2000,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c164fd0>,
#    <gedcom.element.individual.IndividualElement at 0x10c025f98>],
#   '@P240@'],
#  ['Stephen Michael', 'Partridge', 'M', 1962, -1, [], '@P241@'],
#  ['Anne Rosemary', 'Barr', 'F', 1907, 1979, [], '@P242@'],
#  ['Harris Bronston', 'Holt', 'M', 1908, 1971, [], '@P243@'],
#  ['Amanda Moore',
#   'Favret',
#   'F',
#   1992,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c16dc88>,
#    <gedcom.element.individual.IndividualElement at 0x10c0536d8>],
#   '@P244@'],
#  ['Rebecca Margaret',
#   'Favret',
#   'F',
#   1989,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c16dc88>,
#    <gedcom.element.individual.IndividualElement at 0x10c0536d8>],
#   '@P245@'],
#  ['Martin Augustine', 'Favret', 'U', 1962, -1, [], '@P246@'],
#  ['Ellen',
#   'Holt',
#   'F',
#   1937,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c169b38>,
#    <gedcom.element.individual.IndividualElement at 0x10c166518>],
#   '@P247@'],
#  ['Ann-Lew Twyman',
#   'Holt',
#   'F',
#   1949,
#   2016,
#   [<gedcom.element.individual.IndividualElement at 0x10c169b38>,
#    <gedcom.element.individual.IndividualElement at 0x10c166518>],
#   '@P248@'],
#  ['Jean Chrisophe',
#   'Perez',
#   'M',
#   2007,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c046128>,
#    <gedcom.element.individual.IndividualElement at 0x10c177160>],
#   '@P249@'],
#  ['Sarah Biddle',
#   'Holt',
#   'F',
#   2008,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c046128>,
#    <gedcom.element.individual.IndividualElement at 0x10c177160>],
#   '@P250@'],
#  ['Garrett James',
#   'Holt',
#   'M',
#   2006,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c046128>,
#    <gedcom.element.individual.IndividualElement at 0x10c177160>],
#   '@P251@'],
#  ['Mary', "O'Hagin", 'F', 1973, -1, [], '@P252@'],
#  ['Margaret Rose',
#   'Titcomb',
#   'F',
#   2001,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c177c50>,
#    <gedcom.element.individual.IndividualElement at 0x10c0440f0>],
#   '@P253@'],
#  ['Timothy Douglas', 'Titcomb', 'M', 1958, -1, [], '@P254@'],
#  ['Hadleigh Parker',
#   'James',
#   'F',
#   2011,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c086be0>,
#    <gedcom.element.individual.IndividualElement at 0x10c17c2e8>],
#   '@P255@'],
#  ['Addison  Ruth',
#   'James',
#   'F',
#   2009,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c086be0>,
#    <gedcom.element.individual.IndividualElement at 0x10c17c2e8>],
#   '@P256@'],
#  ['Faith Jordan', 'Peters', 'F', 1978, -1, [], '@P257@'],
#  ['Alexander',
#   'Castanos',
#   'M',
#   2016,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c17f0b8>,
#    <gedcom.element.individual.IndividualElement at 0x10c0843c8>],
#   '@P258@'],
#  ['Ryan Michael', 'Castanos', 'M', 1982, -1, [], '@P259@'],
#  ['Derek Alan',
#   'Sibinga',
#   'M',
#   1997,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0b2a90>,
#    <gedcom.element.individual.IndividualElement at 0x10c17fe80>],
#   '@P260@'],
#  ['Rebecca Mary',
#   'Sibinga',
#   'F',
#   1993,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0b2a90>,
#    <gedcom.element.individual.IndividualElement at 0x10c17fe80>],
#   '@P261@'],
#  ['Mariann', 'Davis', 'F', 1964, -1, [], '@P262@'],
#  ['Dora Marie Sibinga',
#   'Hilker',
#   'F',
#   2001,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c180828>,
#    <gedcom.element.individual.IndividualElement at 0x10c0aba58>],
#   '@P263@'],
#  ['Kenneth John', 'Hilker', 'M', 1966, -1, [], '@P264@'],
#  ['Gale',
#   'Gosselink',
#   'F',
#   1989,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0f6c88>,
#    <gedcom.element.individual.IndividualElement at 0x10c1846a0>],
#   '@P265@'],
#  ['Janea Kelly',
#   'Gosselink',
#   'F',
#   1991,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0f6c88>,
#    <gedcom.element.individual.IndividualElement at 0x10c1846a0>],
#   '@P266@'],
#  ['Mary Elizabeth', 'Ward', 'F', 1964, -1, [], '@P267@'],
#  ['Ricardo',
#   'Gosselink',
#   'M',
#   1989,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0f6c88>,
#    <gedcom.element.individual.IndividualElement at 0x10c1846a0>],
#   '@P268@'],
#  ['Gordon',
#   'Gosselink',
#   'M',
#   1987,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0f6c88>,
#    <gedcom.element.individual.IndividualElement at 0x10c1846a0>],
#   '@P269@'],
#  ['Katherine Elizabeth',
#   'Johannes',
#   'F',
#   1998,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c185978>,
#    <gedcom.element.individual.IndividualElement at 0x10c0f4ef0>],
#   '@P270@'],
#  ['Robert Alan', 'Johannes', 'M', 1962, -1, [], '@P271@'],
#  ['John Addison',
#   'Bradbeer',
#   'M',
#   2003,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0b7208>,
#    <gedcom.element.individual.IndividualElement at 0x10c187f98>],
#   '@P272@'],
#  ['Thomas Hutton',
#   'Bradbeer',
#   'M',
#   2000,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0b7208>,
#    <gedcom.element.individual.IndividualElement at 0x10c187f98>],
#   '@P273@'],
#  ['Peter Quinney',
#   'Bradbeer',
#   'M',
#   1998,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0b7208>,
#    <gedcom.element.individual.IndividualElement at 0x10c187f98>],
#   '@P274@'],
#  ['James Biddle',
#   'Bradbeer',
#   'M',
#   1996,
#   -1,
#   [<gedcom.element.individual.IndividualElement at 0x10c0b7208>,
#    <gedcom.element.individual.IndividualElement at 0x10c187f98>],
#   '@P275@'],
#  ['Carol Elizabeth', 'Hastings', 'F', -1, -1, [], '@P276@']]

# %%
my_df = pd.DataFrame(data, columns=['first', 'last', 'sex', 'DOB', 'DOD', 'parents', 'INDI_ID'])

# %%
my_df[1:20]
# Out:
#                 first      last sex   DOB   DOD  \
# 1                Mary    Hutton   F  1869  1925
# 2                Mary     Hewes   F  1842  1874
# 3        John William    Biddle   M  1835  1916
# 4      Addison Hutton    Biddle   M  1903  1912
# 5                Ruth    Biddle   F  1906  1969
# 6      Rebecca Hutton    Biddle   F  1901  1991
# 7   Elizabeth Rebecca    Biddle   F  1897  1975
# 8             Dorothy    Biddle   F  1900  1985
# 9          Mary Hewes    Biddle   F  1898  1963
# 10          Ruth Ella  Chambers   F  1870  1948
# 11            William    Biddle   M  1806  1887
# 12   Elizabeth Cesson    Biddle   F    -1  1881
# 13            William    Biddle   M  1863  1948
# 14            Rebecca    Savery   F  1836  1902
# 15            Addison    Hutton   M  1834  1916
# 16            Sarah S   Garrett   F  1819  1853
# 17           Edward C     Hewes   M  1821  1880
# 18      Margaret Cope     James   F  1935  1979
# 19    Caroline Biddle     James   F  1932  2012
#
#                                  parents INDI_ID
# 1   [0 @P16@ INDI\r\n, 0 @P15@ INDI\r\n]    @P2@
# 2   [0 @P18@ INDI\r\n, 0 @P17@ INDI\r\n]    @P3@
# 3   [0 @P12@ INDI\r\n, 0 @P13@ INDI\r\n]    @P4@
# 4     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P5@
# 5     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P6@
# 6     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P7@
# 7     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P8@
# 8     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]    @P9@
# 9     [0 @P1@ INDI\r\n, 0 @P2@ INDI\r\n]   @P10@
# 10                                    []   @P11@
# 11                                    []   @P12@
# 12                                    []   @P13@
# 13    [0 @P4@ INDI\r\n, 0 @P3@ INDI\r\n]   @P14@
# 14                                    []   @P15@
# 15  [0 @P39@ INDI\r\n, 0 @P40@ INDI\r\n]   @P16@
# 16                                    []   @P17@
# 17                                    []   @P18@
# 18   [0 @P23@ INDI\r\n, 0 @P9@ INDI\r\n]   @P19@
# 19   [0 @P23@ INDI\r\n, 0 @P9@ INDI\r\n]   @P20@

# %% [markdown]
# This is getting close, but I want to split the parents column into Parent1 and Parent2 at the comma. However, I can't do that until I fill the empty values ([]). These are not na values (see below for the .isna() test), do not respond to calling '[]', and do not seem to be actually empty either.

# %% [markdown]
# I've tried lots of ways of taking out the [] in the parents column-- the easiest by far was search and replace in Excel as Regex has been difficult with [] characters. But that takes the gedcom parser back a level and loses the individual @P23@ tag, which marks each individual with a unique identifier. (see below, my_df2) Additionally, I'll need to replace the -1 for an unknown or nonexistent date with NaN.

# %%
my_df.isna().head()
# Out:
#    first   last    sex    DOB    DOD  parents  INDI_ID
# 0  False  False  False  False  False    False    False
# 1  False  False  False  False  False    False    False
# 2  False  False  False  False  False    False    False
# 3  False  False  False  False  False    False    False
# 4  False  False  False  False  False    False    False

# %%
#my_df[['parent_1', 'parent_2']] = my_df.parents.str.split(",", expand=True)

# %%
#for i in my_df[parents]:
 #   if i

# %%
my_df.to_csv('JGB_MHB.csv')

# %%
my_df2 = pd.read_csv('JGB_MHB.csv') #this csv has had empty values replaced using Excel

# %%
my_df2.head()
# Out:
#    Unnamed: 0           first    last sex   DOB   DOD  \
# 0           0   James Garrett  Biddle   M  1868  1947
# 1           1            Mary  Hutton   F  1869  1925
# 2           2            Mary   Hewes   F  1842  1874
# 3           3    John William  Biddle   M  1835  1916
# 4           4  Addison Hutton  Biddle   M  1903  1912
#
#                                              parents INDI_ID
# 0  [<gedcom.element.individual.IndividualElement ...    @P1@
# 1  [<gedcom.element.individual.IndividualElement ...    @P2@
# 2  [<gedcom.element.individual.IndividualElement ...    @P3@
# 3  [<gedcom.element.individual.IndividualElement ...    @P4@
# 4  [<gedcom.element.individual.IndividualElement ...    @P5@
